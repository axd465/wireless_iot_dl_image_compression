# %% [markdown]
# ### Import Statements

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import tensorflow_datasets as tfds
import os
import shutil
import imageio
import scipy
import pandas as pd
from functools import partial
from utils.history_utils import save_history

GPU = 1
use_mixed_prec = False

physical_gpus = tf.config.list_physical_devices('GPU')
if physical_gpus:
    try:
        # Disable GPU
        tf.config.set_visible_devices(physical_gpus[GPU:GPU+1], 'GPU')
        visible_gpus = tf.config.get_visible_devices('GPU')
        print("Num Visible Physical GPUs: ", len(physical_gpus),
              "\nNum Visible GPUs Available: ", len(visible_gpus))
        logical_gpus = tf.config.list_logical_devices('GPU')
        print(len(visible_gpus), "Visible GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Virtual devices must be set before GPUs have been initialized
        print(e)

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
MAP_AUTOTUNE = int(os.cpu_count()*3/4)#tf.data.AUTOTUNE#os.cpu_count()#int(os.cpu_count()*3/4)
AUTOTUNE = tf.data.AUTOTUNE
print('Tensorflow version: ' + tf.__version__)
os.environ['NO_GCE_CHECK'] = 'true'

# For Mixed Precision
from tensorflow.keras import mixed_precision
if use_mixed_prec:
    mixed_precision.set_global_policy('mixed_float16')
# Out:
# Num Visible Physical GPUs:  2
# Num Visible GPUs Available:  1
# 1 Visible GPUs, 1 Logical GPUs
# Tensorflow version: 2.8.0

# %% [markdown]
# ## Creating Dataset:

# %%
builder = tfds.ImageFolder('./data', shape=(None, None, 3))

# %%
print(builder.info)
metadata = builder.info
# Out:
# tfds.core.DatasetInfo(
#     name='image_folder',
#     full_name='image_folder/1.0.0',
#     description="""
#     Generic image classification dataset.
#     """,
#     homepage='https://www.tensorflow.org/datasets/catalog/image_folder',
#     data_path='./data',
#     download_size=Unknown size,
#     dataset_size=Unknown size,
#     features=FeaturesDict({
#         'image': Image(shape=(None, None, 3), dtype=tf.uint8),
#         'image/filename': Text(shape=(), dtype=tf.string),
#         'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=1),
#     }),
#     supervised_keys=('image', 'label'),
#     disable_shuffling=False,
#     splits={
#         'train': <SplitInfo num_examples=800, num_shards=1>,
#         'val': <SplitInfo num_examples=100, num_shards=1>,
#     },
#     citation="""""",
# )

# %%
# tf.data.experimental.save(dataset, path)
# new_dataset = tf.data.experimental.load(path)

# %% [markdown]
# ## Creating Input Pipeline

# %%
from utils.downsampling_utils import downsample, downsample_zerofill, downsample_interp
from utils.augmentation_utils import augment, keras_augment, normalize, augment_noise

# %%
(train_ds, val_ds) = builder.as_dataset(split=['train', 'val'], shuffle_files=False)

# %%
NUM_TRAIN = tf.data.experimental.cardinality(train_ds).numpy()
NUM_VAL = tf.data.experimental.cardinality(val_ds).numpy()

# %%
train_ds = train_ds.map(lambda x: x['image'],
                        num_parallel_calls=AUTOTUNE).prefetch(AUTOTUNE)
val_ds = val_ds.map(lambda x: x['image'],
                    num_parallel_calls=AUTOTUNE).prefetch(AUTOTUNE)

# %%
norm_range = [0, 1]
norm_func = partial(normalize, clip=False, out_range=norm_range, if_uint8=True)
train_ds = train_ds.map(norm_func,
                        num_parallel_calls=AUTOTUNE).prefetch(AUTOTUNE)
val_ds = val_ds.map(norm_func,
                    num_parallel_calls=AUTOTUNE).prefetch(AUTOTUNE)

# %%
norm_range = [0, 1]
CROP_SIZE = (256, 256, 3)
INIT_SEED = 7
PROB_OF_AUG = 1/2#1/3 # prob [0,1]
MAX_BRIGHT_SHIFT = 0.1 # in range [0,1]
LOWER_CONTRAST_FACTOR = 0.5#0.75
UPPER_CONTRAST_FACTOR = 1.5#1.25
MAX_HUE_DELTA = 0.05
JPEG_QUALITY_RANGE = [75, 100]
SAT_FACTOR_RANGE = [0.9, 1.1]


GAUSS_NOISE_MEAN = 0
LOWER_GAUSS_NOISE_STD = 0.05
UPPER_GAUSS_NOISE_STD = 0.25

MAX_SHIFT_FRACTION_X_Y = [0.1, 0.1]
MAX_ROTATION_DEG = 10
MAX_ZOOM_FRACTION_X_Y = [0.9, 0.9]
MAX_CHANNEL_INTENSITY_SHIFT = 0.1
SHEAR_INTENSITY = 0.1
FILL_MODE = 'nearest' #'constant'
INTERP_ORD = 3 # No Interp

# %%
main_augment = partial(augment, prob=PROB_OF_AUG,
                       max_shift=MAX_BRIGHT_SHIFT,
                       con_factor_range=[LOWER_CONTRAST_FACTOR, 
                                         UPPER_CONTRAST_FACTOR],
                       max_hue_delta=MAX_HUE_DELTA,
                       jpeg_quality_range=JPEG_QUALITY_RANGE,
                       sat_factor_range=SAT_FACTOR_RANGE,
                       out_range=norm_range,
                       seed=INIT_SEED)
secondary_augment = partial(augment_noise, prob=PROB_OF_AUG,
                            mean=GAUSS_NOISE_MEAN,
                            std_lower=LOWER_GAUSS_NOISE_STD,
                            std_upper=UPPER_GAUSS_NOISE_STD,
                            out_range=norm_range,
                            seed=INIT_SEED)

rand_crop = partial(tf.image.random_crop, size=CROP_SIZE)

lambda_map_func = partial(keras_augment, fill_mode=FILL_MODE,
                          interpolation_order=INTERP_ORD,
                          max_shift_xy=MAX_SHIFT_FRACTION_X_Y,
                          rg=MAX_ROTATION_DEG,
                          zoom_range=MAX_ZOOM_FRACTION_X_Y,
                          intensity_range=MAX_CHANNEL_INTENSITY_SHIFT,
                          shear_intensity=SHEAR_INTENSITY,
                          out_range=norm_range)

lambda_func = lambda x: tf.numpy_function(lambda_map_func, [x], tf.float32)

# %%
train_ds = (
    train_ds
    .cache()
    .map(rand_crop, num_parallel_calls=MAP_AUTOTUNE)
    .prefetch(AUTOTUNE)
    .map(main_augment, num_parallel_calls=MAP_AUTOTUNE)
    .prefetch(AUTOTUNE)
    .map(secondary_augment, num_parallel_calls=MAP_AUTOTUNE)
    .prefetch(AUTOTUNE)
    .map(lambda_func, num_parallel_calls=MAP_AUTOTUNE)
    .prefetch(AUTOTUNE)
)
val_ds = (
    val_ds
    .cache()
    .map(rand_crop, num_parallel_calls=MAP_AUTOTUNE)
    .prefetch(AUTOTUNE)
)

# %%
# img = next(iter(test_ds))
# figsize = (7, 7)
# fig = plt.figure(figsize=figsize)
# ax = fig.add_axes([0, 0, 1, 1])
# ax.axis('off')
# ax.imshow(img)
# plt.title('Test Image')
# plt.show()

# %%
# img = next(iter(test_ds))
# figsize = (7, 7)
# fig = plt.figure(figsize=figsize)
# ax = fig.add_axes([0, 0, 1, 1])
# ax.axis('off')
# ax.imshow(img)
# plt.title('Test Image')
# plt.show()

# %% [markdown]
# ## Define Model Input and Ground Truth

# %%
def define_in_out(x):
    return x, x

# %%
# from utils.jpeg_utils import jpeg_encode_decode
# QUALITY = 70

# def define_in_out(x):
#     return jpeg_encode_decode(x, QUALITY), x

# %%
train_ds = (
    train_ds
    .map(define_in_out, num_parallel_calls=MAP_AUTOTUNE)
    .prefetch(AUTOTUNE)
)
val_ds = (
    val_ds
    .map(define_in_out, num_parallel_calls=MAP_AUTOTUNE)
    .prefetch(AUTOTUNE)
)

# %% [markdown]
# ## Model Training:

# %%
# Import Model:
# from models.AutoEncoder import getModel
# from models.AutoEncoder_v2 import getModel
# from models.AutoEncoder_v3 import getModel
# from models.AutoEncoder_v4 import getModel
# from models.AutoEncoder_v5 import getModel
# from models.AutoEncoder_v6 import getModel
# from models.AutoEncoder_v7 import getModel
# from models.AutoEncoder_v8 import getModel
# from models.AutoEncoder_v9 import getModel
# from models.AutoEncoder_v10 import getModel
# from models.AutoEncoder_v11 import getModel
# from models.AutoEncoder_v12 import getModel
# from models.AutoEncoder_v13 import getModel
# from models.AutoEncoder_v14 import getModel
# from models.AutoEncoder_v15 import getModel
# from models.AutoEncoder_v16_jarvis import getModel
# from models.AutoEncoder_v16_jarvis1 import getModel
# from models.AutoEncoder_v17_jarvis1 import getModel
# from models.AutoEncoder_v18_jarvis1 import getModel
from models.AutoEncoder_v19_jarvis1 import getModel

# %%
# Hyperparameters:
INPUT_SHAPE = [None, None, 3]
KERNEL_SIZE = [11, 11]#[7, 7]#[11, 11]#[7, 7]
DILATION_RATE = 2
BATCH_SIZE = 32#16#8
EPOCHS = 200
FILTERS = 4#2#4#8#32
# DROP_PROB = 0.05#0.075#0.05#0.075#0.25#0.1#0.05
KERNEL_REGULARIZER = tf.keras.regularizers.L2(0.00001)#None#tf.keras.regularizers.L2(0.0001)#None#tf.keras.regularizers.L2(0.0001)
KERNEL_INITIALIZER = "glorot_normal"#"orthogonal"#"glorot_normal"#"orthogonal"
DROP_PROB = None#0.1#None#0#0.15
INITIAL_LR = 0.005#0.001
LR_DECAY = 0.97#0.96#0.98#0.95#0.9#0.97#0.95#0.97#0.93
LR_DECAY_START = 10#25
ACTIVATION = 'elu'
AUGMENTATIONS = 20#10#1#10
VAL_AUGMENTATIONS = 10#1#10#5#10#100
MODEL_DIR = f'saved_models_{GPU}'
BUFFER_SIZE = 800
UPDATE_INFO_EVERY_X_EPOCHS = 25#47#94#310
delete_previous = True
SAVE_METRIC = 'val_loss'

# %%
model_kwargs = {'filters': FILTERS,
                'kernel_size': KERNEL_SIZE, 
                'activation': ACTIVATION,
                'dilation_rate': DILATION_RATE,
                'prob': DROP_PROB,
                'kernel_initializer': KERNEL_INITIALIZER,
                'kernel_regularizer': KERNEL_REGULARIZER}

# %%
# from utils.model_utils import model_loss
# USE_MSE = False
# if USE_MSE:
#     B1 = 1.0
#     B2 = 0.000075
# else:
#     # MAE
#     B1 = 1.0
#     B2 = 0.004
# loss_func = model_loss(B1, B2, mse = USE_MSE, name='loss')

from utils.model_utils import model_loss, PSNR, SSIM
# B1 = 1.0
# B2 = 0.0025#0.01#0.0025
# B3 = 0.0075 #0.005
# B4 = 0.03 #0.01
# B5 = 0#B1/50
# B6 = 0#B1/50
# weighted_fft = True
# B2 = 0.2#0.1
# loss_func = model_loss(B1, B2, B3, B4, B5, B6, mse=False,
#                        weighted_fft=weighted_fft, name='loss',
#                        input_type=input_type)
B1 = 1
B2 = 0.0025
loss_func = tf.keras.losses.MeanAbsoluteError()#model_loss(B1, B2, mse=True, name='loss')

# %%
# B1 = 0
# B2 = 0
# B3 = 0
# B4 = 0
# B5 = 0
# B6 = 0
# weighted_fft = True
# B2 = 1
# weighted_fft_func = model_loss(B1, B2, B3, B4, B5, B6, mse=False,
#                                weighted_fft=weighted_fft, name='weighted_fft_loss',
#                                input_type=input_type)

# %%
train_ds = (
    train_ds
    .prefetch(AUTOTUNE)
    .shuffle(BUFFER_SIZE)
    .batch(BATCH_SIZE)
    .repeat()
    .prefetch(AUTOTUNE)
)
val_ds = (
    val_ds
    .prefetch(AUTOTUNE)
    .shuffle(BUFFER_SIZE//4)# was //8
    .batch(BATCH_SIZE)
    .repeat()
    .prefetch(AUTOTUNE)
)

# %%
# def scheduler(epoch, lr):
#     if epoch < LR_DECAY_START:
#         return lr
#     else:
#         return lr*LR_DECAY
# def scheduler(epoch, lr):
#     if epoch % 25 != 0 or epoch < 25:
#         return lr
#     else:
#         return lr * 0.5

# def scheduler(epoch, lr):
#     if epoch < LR_DECAY_START:
#         return lr
#     elif epoch >= LR_DECAY_START: #and epoch != 100:
#         return lr*LR_DECAY

#     elif epoch == 100:
#         return INITIAL_LR

# %%
def scheduler(epoch, lr):
    if epoch <= LR_DECAY_START:
        return (epoch/LR_DECAY_START)*INITIAL_LR + INITIAL_LR/10000
    elif epoch < 2*LR_DECAY_START:
        return lr
    elif epoch >= 2*LR_DECAY_START:
        return lr*LR_DECAY

# %%
model = getModel(input_shape=INPUT_SHAPE, **model_kwargs)

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=INITIAL_LR)#, amsgrad=True)#, clipvalue=10)
if use_mixed_prec:
    optimizer = mixed_precision.LossScaleOptimizer(optimizer)
model.compile(optimizer=optimizer,  # pick an optimizer
              loss=loss_func,
              steps_per_execution=((AUGMENTATIONS) * np.ceil(NUM_TRAIN/BATCH_SIZE)) // UPDATE_INFO_EVERY_X_EPOCHS,
              metrics=['mean_absolute_error', 'mean_squared_error', SSIM, PSNR])

# %%
model.summary()
# Out:
# Model: "AutoEncoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  img (InputLayer)               [(None, None, None,  0           []
#                                  3)]
#
#  conv2d (Conv2D)                (None, None, None,   1456        ['img[0][0]']
#                                 4)
#
#  batch_normalization (BatchNorm  (None, None, None,   16         ['conv2d[0][0]']
#  alization)                     4)
#
#  conv2d_1 (Conv2D)              (None, None, None,   1940        ['batch_normalization[0][0]']
#                                 4)
#
#  conv2d_2 (Conv2D)              (None, None, None,   16          ['img[0][0]']
#                                 4)
#
#  batch_normalization_1 (BatchNo  (None, None, None,   16         ['conv2d_1[0][0]']
#  rmalization)                   4)
#
#  batch_normalization_2 (BatchNo  (None, None, None,   16         ['conv2d_2[0][0]']
#  rmalization)                   4)
#
#  add (Add)                      (None, None, None,   0           ['batch_normalization_1[0][0]',
#                                 4)                                'batch_normalization_2[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, None, None,   0           ['add[0][0]']
#                                 4)
#
#  conv2d_3 (Conv2D)              (None, None, None,   3880        ['max_pooling2d[0][0]']
#                                 8)
#
#  batch_normalization_3 (BatchNo  (None, None, None,   32         ['conv2d_3[0][0]']
#  rmalization)                   8)
#
#  conv2d_4 (Conv2D)              (None, None, None,   7752        ['batch_normalization_3[0][0]']
#                                 8)
#
#  conv2d_5 (Conv2D)              (None, None, None,   40          ['max_pooling2d[0][0]']
#                                 8)
#
#  batch_normalization_4 (BatchNo  (None, None, None,   32         ['conv2d_4[0][0]']
#  rmalization)                   8)
#
#  batch_normalization_5 (BatchNo  (None, None, None,   32         ['conv2d_5[0][0]']
#  rmalization)                   8)
#
#  add_1 (Add)                    (None, None, None,   0           ['batch_normalization_4[0][0]',
#                                 8)                                'batch_normalization_5[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, None, None,   0          ['add_1[0][0]']
#                                 8)
#
#  conv2d_6 (Conv2D)              (None, None, None,   15504       ['max_pooling2d_1[0][0]']
#                                 16)
#
#  batch_normalization_6 (BatchNo  (None, None, None,   64         ['conv2d_6[0][0]']
#  rmalization)                   16)
#
#  conv2d_7 (Conv2D)              (None, None, None,   30992       ['batch_normalization_6[0][0]']
#                                 16)
#
#  conv2d_8 (Conv2D)              (None, None, None,   144         ['max_pooling2d_1[0][0]']
#                                 16)
#
#  batch_normalization_7 (BatchNo  (None, None, None,   64         ['conv2d_7[0][0]']
#  rmalization)                   16)
#
#  batch_normalization_8 (BatchNo  (None, None, None,   64         ['conv2d_8[0][0]']
#  rmalization)                   16)
#
#  add_2 (Add)                    (None, None, None,   0           ['batch_normalization_7[0][0]',
#                                 16)                               'batch_normalization_8[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, None, None,   0          ['add_2[0][0]']
#                                 16)
#
#  conv2d_9 (Conv2D)              (None, None, None,   61984       ['max_pooling2d_2[0][0]']
#                                 32)
#
#  batch_normalization_9 (BatchNo  (None, None, None,   128        ['conv2d_9[0][0]']
#  rmalization)                   32)
#
#  conv2d_10 (Conv2D)             (None, None, None,   123936      ['batch_normalization_9[0][0]']
#                                 32)
#
#  conv2d_11 (Conv2D)             (None, None, None,   544         ['max_pooling2d_2[0][0]']
#                                 32)
#
#  batch_normalization_10 (BatchN  (None, None, None,   128        ['conv2d_10[0][0]']
#  ormalization)                  32)
#
#  batch_normalization_11 (BatchN  (None, None, None,   128        ['conv2d_11[0][0]']
#  ormalization)                  32)
#
#  add_3 (Add)                    (None, None, None,   0           ['batch_normalization_10[0][0]',
#                                 32)                               'batch_normalization_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, None, None,   123936      ['add_3[0][0]']
#                                 32)
#
#  batch_normalization_12 (BatchN  (None, None, None,   128        ['conv2d_12[0][0]']
#  ormalization)                  32)
#
#  conv2d_13 (Conv2D)             (None, None, None,   123936      ['batch_normalization_12[0][0]']
#                                 32)
#
#  conv2d_14 (Conv2D)             (None, None, None,   1056        ['add_3[0][0]']
#                                 32)
#
#  batch_normalization_13 (BatchN  (None, None, None,   128        ['conv2d_13[0][0]']
#  ormalization)                  32)
#
#  batch_normalization_14 (BatchN  (None, None, None,   128        ['conv2d_14[0][0]']
#  ormalization)                  32)
#
#  conv2d_15 (Conv2D)             (None, None, None,   544         ['max_pooling2d_2[0][0]']
#                                 32)
#
#  add_4 (Add)                    (None, None, None,   0           ['batch_normalization_13[0][0]',
#                                 32)                               'batch_normalization_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, None, None,   128        ['conv2d_15[0][0]']
#  ormalization)                  32)
#
#  add_5 (Add)                    (None, None, None,   0           ['add_4[0][0]',
#                                 32)                               'batch_normalization_15[0][0]']
#
#  tf.math.reduce_min (TFOpLambda  (None, 1, 1, 1)     0           ['add_5[0][0]']
#  )
#
#  tf.math.reduce_max (TFOpLambda  (None, 1, 1, 1)     0           ['add_5[0][0]']
#  )
#
#  tf.math.subtract (TFOpLambda)  (None, None, None,   0           ['add_5[0][0]',
#                                 32)                               'tf.math.reduce_min[0][0]']
#
#  tf.math.subtract_1 (TFOpLambda  (None, 1, 1, 1)     0           ['tf.math.reduce_max[0][0]',
#  )                                                                'tf.math.reduce_min[0][0]']
#
#  tf.math.divide_no_nan (TFOpLam  (None, None, None,   0          ['tf.math.subtract[0][0]',
#  bda)                           32)                               'tf.math.subtract_1[0][0]']
#
#  conv2d_17 (Conv2D)             (None, None, None,   123936      ['tf.math.divide_no_nan[0][0]']
#                                 32)
#
#  batch_normalization_17 (BatchN  (None, None, None,   128        ['conv2d_17[0][0]']
#  ormalization)                  32)
#
#  conv2d_18 (Conv2D)             (None, None, None,   123936      ['batch_normalization_17[0][0]']
#                                 32)
#
#  conv2d_19 (Conv2D)             (None, None, None,   1056        ['tf.math.divide_no_nan[0][0]']
#                                 32)
#
#  batch_normalization_18 (BatchN  (None, None, None,   128        ['conv2d_18[0][0]']
#  ormalization)                  32)
#
#  batch_normalization_19 (BatchN  (None, None, None,   128        ['conv2d_19[0][0]']
#  ormalization)                  32)
#
#  add_6 (Add)                    (None, None, None,   0           ['batch_normalization_18[0][0]',
#                                 32)                               'batch_normalization_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, None, None,   123936      ['add_6[0][0]']
#                                 32)
#
#  batch_normalization_20 (BatchN  (None, None, None,   128        ['conv2d_20[0][0]']
#  ormalization)                  32)
#
#  conv2d_21 (Conv2D)             (None, None, None,   123936      ['batch_normalization_20[0][0]']
#                                 32)
#
#  conv2d_22 (Conv2D)             (None, None, None,   1056        ['add_6[0][0]']
#                                 32)
#
#  batch_normalization_21 (BatchN  (None, None, None,   128        ['conv2d_21[0][0]']
#  ormalization)                  32)
#
#  batch_normalization_22 (BatchN  (None, None, None,   128        ['conv2d_22[0][0]']
#  ormalization)                  32)
#
#  conv2d_16 (Conv2D)             (None, None, None,   1056        ['tf.math.divide_no_nan[0][0]']
#                                 32)
#
#  add_7 (Add)                    (None, None, None,   0           ['batch_normalization_21[0][0]',
#                                 32)                               'batch_normalization_22[0][0]']
#
#  batch_normalization_16 (BatchN  (None, None, None,   128        ['conv2d_16[0][0]']
#  ormalization)                  32)
#
#  add_8 (Add)                    (None, None, None,   0           ['add_7[0][0]',
#                                 32)                               'batch_normalization_16[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, None, None,   65568      ['add_8[0][0]']
#  ose)                           32)
#
#  batch_normalization_23 (BatchN  (None, None, None,   128        ['conv2d_transpose[0][0]']
#  ormalization)                  32)
#
#  conv2d_23 (Conv2D)             (None, None, None,   61968       ['batch_normalization_23[0][0]']
#                                 16)
#
#  batch_normalization_24 (BatchN  (None, None, None,   64         ['conv2d_23[0][0]']
#  ormalization)                  16)
#
#  conv2d_24 (Conv2D)             (None, None, None,   30992       ['batch_normalization_24[0][0]']
#                                 16)
#
#  conv2d_25 (Conv2D)             (None, None, None,   528         ['batch_normalization_23[0][0]']
#                                 16)
#
#  batch_normalization_25 (BatchN  (None, None, None,   64         ['conv2d_24[0][0]']
#  ormalization)                  16)
#
#  batch_normalization_26 (BatchN  (None, None, None,   64         ['conv2d_25[0][0]']
#  ormalization)                  16)
#
#  add_9 (Add)                    (None, None, None,   0           ['batch_normalization_25[0][0]',
#                                 16)                               'batch_normalization_26[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, None, None,   16400      ['add_9[0][0]']
#  spose)                         16)
#
#  batch_normalization_27 (BatchN  (None, None, None,   64         ['conv2d_transpose_1[0][0]']
#  ormalization)                  16)
#
#  conv2d_26 (Conv2D)             (None, None, None,   15496       ['batch_normalization_27[0][0]']
#                                 8)
#
#  batch_normalization_28 (BatchN  (None, None, None,   32         ['conv2d_26[0][0]']
#  ormalization)                  8)
#
#  conv2d_27 (Conv2D)             (None, None, None,   7752        ['batch_normalization_28[0][0]']
#                                 8)
#
#  conv2d_28 (Conv2D)             (None, None, None,   136         ['batch_normalization_27[0][0]']
#                                 8)
#
#  batch_normalization_29 (BatchN  (None, None, None,   32         ['conv2d_27[0][0]']
#  ormalization)                  8)
#
#  batch_normalization_30 (BatchN  (None, None, None,   32         ['conv2d_28[0][0]']
#  ormalization)                  8)
#
#  add_10 (Add)                   (None, None, None,   0           ['batch_normalization_29[0][0]',
#                                 8)                                'batch_normalization_30[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, None, None,   4104       ['add_10[0][0]']
#  spose)                         8)
#
#  batch_normalization_31 (BatchN  (None, None, None,   32         ['conv2d_transpose_2[0][0]']
#  ormalization)                  8)
#
#  conv2d_29 (Conv2D)             (None, None, None,   3876        ['batch_normalization_31[0][0]']
#                                 4)
#
#  batch_normalization_32 (BatchN  (None, None, None,   16         ['conv2d_29[0][0]']
#  ormalization)                  4)
#
#  conv2d_30 (Conv2D)             (None, None, None,   1940        ['batch_normalization_32[0][0]']
#                                 4)
#
#  conv2d_31 (Conv2D)             (None, None, None,   36          ['batch_normalization_31[0][0]']
#                                 4)
#
#  batch_normalization_33 (BatchN  (None, None, None,   16         ['conv2d_30[0][0]']
#  ormalization)                  4)
#
#  batch_normalization_34 (BatchN  (None, None, None,   16         ['conv2d_31[0][0]']
#  ormalization)                  4)
#
#  add_11 (Add)                   (None, None, None,   0           ['batch_normalization_33[0][0]',
#                                 4)                                'batch_normalization_34[0][0]']
#
#  conv2d_32 (Conv2D)             (None, None, None,   15          ['add_11[0][0]']
#                                 3)
#
#  tf.math.reduce_min_1 (TFOpLamb  (None, 1, 1, 1)     0           ['conv2d_32[0][0]']
#  da)
#
#  tf.math.reduce_max_1 (TFOpLamb  (None, 1, 1, 1)     0           ['conv2d_32[0][0]']
#  da)
#
#  tf.math.subtract_2 (TFOpLambda  (None, None, None,   0          ['conv2d_32[0][0]',
#  )                              3)                                'tf.math.reduce_min_1[0][0]']
#
#  tf.math.subtract_3 (TFOpLambda  (None, 1, 1, 1)     0           ['tf.math.reduce_max_1[0][0]',
#  )                                                                'tf.math.reduce_min_1[0][0]']
#
#  tf.math.divide_no_nan_1 (TFOpL  (None, None, None,   0          ['tf.math.subtract_2[0][0]',
#  ambda)                         3)                                'tf.math.subtract_3[0][0]']
#
# ==================================================================================================
# Total params: 1,208,071
# Trainable params: 1,206,727
# Non-trainable params: 1,344
# __________________________________________________________________________________________________

# %%
if not os.path.exists(MODEL_DIR):
    os.mkdir(MODEL_DIR)
elif delete_previous:
    shutil.rmtree(MODEL_DIR)
    os.mkdir(MODEL_DIR)

lr_schedule = tf.keras.callbacks.LearningRateScheduler(scheduler)
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=os.path.join(MODEL_DIR, 
                                                                            'saved_model-epoch_{epoch:02d}-' + 
                                                                            SAVE_METRIC + '_{' + 
                                                                            SAVE_METRIC + ':.5f}.h5'),
                                                      monitor=SAVE_METRIC,
                                                      verbose=0,
                                                      save_best_only=True,
                                                      save_weights_only=False,
                                                      mode='min',
                                                      save_freq='epoch')

my_callbacks = [model_checkpoint, lr_schedule]

history = model.fit(train_ds,
                    steps_per_epoch=AUGMENTATIONS*np.ceil(NUM_TRAIN/BATCH_SIZE),
                    epochs=EPOCHS,
                    callbacks=my_callbacks,
                    validation_data=val_ds,
                    validation_steps=VAL_AUGMENTATIONS*np.ceil(NUM_VAL/BATCH_SIZE),
                    max_queue_size=10*AUGMENTATIONS*np.ceil(NUM_TRAIN/BATCH_SIZE))
# Out:
# Epoch 1/200
# 500/500 [==============================] - 300s 599ms/step - loss: 0.2473 - mean_absolute_error: 0.2408 - mean_squared_error: 0.0819 - SSIM: 0.0733 - PSNR: 11.3787 - val_loss: 0.2276 - val_mean_absolute_error: 0.2212 - val_mean_squared_error: 0.0691 - val_SSIM: 0.0851 - val_PSNR: 12.0303 - lr: 5.0000e-07
# Epoch 2/200
# 500/500 [==============================] - 241s 482ms/step - loss: 0.1276 - mean_absolute_error: 0.1211 - mean_squared_error: 0.0261 - SSIM: 0.3045 - PSNR: 16.8476 - val_loss: 0.1106 - val_mean_absolute_error: 0.1041 - val_mean_squared_error: 0.0194 - val_SSIM: 0.3724 - val_PSNR: 17.8031 - lr: 5.0050e-04
# Epoch 3/200
# 500/500 [==============================] - 242s 485ms/step - loss: 0.0983 - mean_absolute_error: 0.0918 - mean_squared_error: 0.0154 - SSIM: 0.4006 - PSNR: 19.0416 - val_loss: 0.0947 - val_mean_absolute_error: 0.0883 - val_mean_squared_error: 0.0140 - val_SSIM: 0.4337 - val_PSNR: 19.2592 - lr: 0.0010
# Epoch 4/200
- mean_absolute_error: 0.0435 - mean_squared_error: 0.0049 - SSIM: 0.6663 - PSNR: 25.5638 - val_loss: 0.0442 - val_mean_absolute_error: 0.0421 - val_mean_squared_error: 0.0046 - val_SSIM: 0.6835 - val_PSNR: 25.3259 - lr: 9.0830e-04
# Epoch 77/200
# 500/500 [==============================] - 242s 483ms/step - loss: 0.0463 - mean_absolute_error: 0.0442 - mean_squared_error: 0.0049 - SSIM: 0.6647 - PSNR: 25.4556 - val_loss: 0.0429 - val_mean_absolute_error: 0.0408 - val_mean_squared_error: 0.0044 - val_SSIM: 0.6708 - val_PSNR: 25.5040 - lr: 8.8105e-04
# Epoch 78/200
# 500/500 [==============================] - 241s 483ms/step - loss: 0.0459 - mean_absolute_error: 0.0438 - mean_squared_error: 0.0049 - SSIM: 0.6669 - PSNR: 25.5458 - val_loss: 0.0468 - val_mean_absolute_error: 0.0446 - val_mean_squared_error: 0.0048 - val_SSIM: 0.6834 - val_PSNR: 24.7417 - lr: 8.5462e-04
# Epoch 79/200
# 500/500 [==============================] - 241s 481ms/step - loss: 0.0459 - mean_absolute_error: 0.0438 - mean_squared_error: 0.0049 - SSIM: 0.6646 - PSNR: 25.5637 - val_loss: 0.0485 - val_mean_absolute_error: 0.0463 - val_mean_squared_error: 0.0051 - val_SSIM: 0.6677 - val_PSNR: 24.5650 - lr: 8.2898e-04
# Epoch 80/200
# 500/500 [==============================] - 254s 509ms/step - loss: 0.0455 - mean_absolute_error: 0.0434 - mean_squared_error: 0.0049 - SSIM: 0.6649 - PSNR: 25.6462 - val_loss: 0.0409 - val_mean_absolute_error: 0.0388 - val_mean_squared_error: 0.0043 - val_SSIM: 0.6857 - val_PSNR: 25.8836 - lr: 8.0411e-04
# Epoch 81/200
# 500/500 [==============================] - 228s 456ms/step - loss: 0.0456 - mean_absolute_error: 0.0435 - mean_squared_error: 0.0049 - SSIM: 0.6664 - PSNR: 25.6047 - val_loss: 0.0444 - val_mean_absolute_error: 0.0423 - val_mean_squared_error: 0.0045 - val_SSIM: 0.6938 - val_PSNR: 25.3046 - lr: 7.7999e-04
# Epoch 82/200
# 500/500 [==============================] - 241s 481ms/step - loss: 0.0455 - mean_absolute_error: 0.0434 - mean_squared_error: 0.0049 - SSIM: 0.6669 - PSNR: 25.6282 - val_loss: 0.0446 - val_mean_absolute_error: 0.0425 - val_mean_squared_error: 0.0045 - val_SSIM: 0.6872 - val_PSNR: 25.2528 - lr: 7.5659e-04
# Epoch 83/200
# 500/500 [==============================] - 241s 483ms/step - loss: 0.0457 - mean_absolute_error: 0.0436 - mean_squared_error: 0.0049 - SSIM: 0.6662 - PSNR: 25.6113 - val_loss: 0.0441 - val_mean_absolute_error: 0.0420 - val_mean_squared_error: 0.0045 - val_SSIM: 0.6908 - val_PSNR: 25.2932 - lr: 7.3389e-04
# Epoch 84/200
# 500/500 [==============================] - 256s 513ms/step - loss: 0.0451 - mean_absolute_error: 0.0431 - mean_squared_error: 0.0048 - SSIM: 0.6707 - PSNR: 25.6765 - val_loss: 0.0386 - val_mean_absolute_error: 0.0366 - val_mean_squared_error: 0.0039 - val_SSIM: 0.7011 - val_PSNR: 26.3447 - lr: 7.1188e-04
# Epoch 85/200
# 500/500 [==============================] - 227s 455ms/step - loss: 0.0454 - mean_absolute_error: 0.0433 - mean_squared_error: 0.0048 - SSIM: 0.6682 - PSNR: 25.6549 - val_loss: 0.0472 - val_mean_absolute_error: 0.0451 - val_mean_squared_error: 0.0048 - val_SSIM: 0.6877 - val_PSNR: 24.8936 - lr: 6.9052e-04
# Epoch 86/200
# 500/500 [==============================] - 241s 482ms/step - loss: 0.0454 - mean_absolute_error: 0.0433 - mean_squared_error: 0.0048 - SSIM: 0.6677 - PSNR: 25.6616 - val_loss: 0.0425 - val_mean_absolute_error: 0.0405 - val_mean_squared_error: 0.0044 - val_SSIM: 0.6907 - val_PSNR: 25.5119 - lr: 6.6980e-04
# Epoch 87/200
# 500/500 [==============================] - 241s 482ms/step - loss: 0.0453 - mean_absolute_error: 0.0433 - mean_squared_error: 0.0048 - SSIM: 0.6688 - PSNR: 25.6511 - val_loss: 0.0421 - val_mean_absolute_error: 0.0400 - val_mean_squared_error: 0.0042 - val_SSIM: 0.6875 - val_PSNR: 25.6244 - lr: 6.4971e-04
# Epoch 88/200
# 500/500 [==============================] - 241s 483ms/step - loss: 0.0446 - mean_absolute_error: 0.0426 - mean_squared_error: 0.0048 - SSIM: 0.6707 - PSNR: 25.7978 - val_loss: 0.0418 - val_mean_absolute_error: 0.0398 - val_mean_squared_error: 0.0043 - val_SSIM: 0.6957 - val_PSNR: 25.7773 - lr: 6.3022e-04
# Epoch 89/200
# 500/500 [==============================] - 241s 482ms/step - loss: 0.0447 - mean_absolute_error: 0.0428 - mean_squared_error: 0.0047 - SSIM: 0.6720 - PSNR: 25.7675 - val_loss: 0.0410 - val_mean_absolute_error: 0.0391 - val_mean_squared_error: 0.0041 - val_SSIM: 0.6912 - val_PSNR: 25.9718 - lr: 6.1131e-04
# Epoch 90/200
# 500/500 [==============================] - 241s 482ms/step - loss: 0.0450 - mean_absolute_error: 0.0431 - mean_squared_error: 0.0048 - SSIM: 0.6708 - PSNR: 25.7110 - val_loss: 0.0393 - val_mean_absolute_error: 0.0373 - val_mean_squared_error: 0.0041 - val_SSIM: 0.6977 - val_PSNR: 26.3000 - lr: 5.9297e-04
# Epoch 91/200
# 500/500 [==============================] - 240s 480ms/step - loss: 0.0448 - mean_absolute_error: 0.0429 - mean_squared_error: 0.0048 - SSIM: 0.6722 - PSNR: 25.7406 - val_loss: 0.0414 - val_mean_absolute_error: 0.0394 - val_mean_squared_error: 0.0043 - val_SSIM: 0.6834 - val_PSNR: 25.8934 - lr: 5.7518e-04
# Epoch 92/200
# 500/500 [==============================] - 240s 480ms/step - loss: 0.0448 - mean_absolute_error: 0.0429 - mean_squared_error: 0.0048 - SSIM: 0.6707 - PSNR: 25.7850 - val_loss: 0.0405 - val_mean_absolute_error: 0.0386 - val_mean_squared_error: 0.0040 - val_SSIM: 0.6948 - val_PSNR: 26.0273 - lr: 5.5793e-04
# Epoch 93/200
# 500/500 [==============================] - 241s 482ms/step - loss: 0.0440 - mean_absolute_error: 0.0421 - mean_squared_error: 0.0046 - SSIM: 0.6766 - PSNR: 25.9027 - val_loss: 0.0429 - val_mean_absolute_error: 0.0410 - val_mean_squared_error: 0.0044 - val_SSIM: 0.6849 - val_PSNR: 25.6151 - lr: 5.4119e-04
# Epoch 94/200
# 500/500 [==============================] - 241s 483ms/step - loss: 0.0447 - mean_absolute_error: 0.0428 - mean_squared_error: 0.0048 - SSIM: 0.6720 - PSNR: 25.7775 - val_loss: 0.0402 - val_mean_absolute_error: 0.0383 - val_mean_squared_error: 0.0042 - val_SSIM: 0.6990 - val_PSNR: 26.0569 - lr: 5.2495e-04
# Epoch 95/200
# 500/500 [==============================] - 241s 482ms/step - loss: 0.0444 - mean_absolute_error: 0.0425 - mean_squared_error: 0.0047 - SSIM: 0.6731 - PSNR: 25.8370 - val_loss: 0.0396 - val_mean_absolute_error: 0.0377 - val_mean_squared_error: 0.0040 - val_SSIM: 0.6985 - val_PSNR: 26.1442 - lr: 5.0921e-04
# Epoch 96/200
# 500/500 [==============================] - 241s 483ms/step - loss: 0.0442 - mean_absolute_error: 0.0423 - mean_squared_error: 0.0047 - SSIM: 0.6764 - PSNR: 25.8883 - val_loss: 0.0397 - val_mean_absolute_error: 0.0378 - val_mean_squared_error: 0.0042 - val_SSIM: 0.7029 - val_PSNR: 26.1200 - lr: 4.9393e-04
# Epoch 97/200
# 500/500 [==============================] - 240s 480ms/step - loss: 0.0446 - mean_absolute_error: 0.0427 - mean_squared_error: 0.
- mean_absolute_error: 0.0424 - mean_squared_error: 0.0047 - SSIM: 0.6731 - PSNR: 25.8709 - val_loss: 0.0398 - val_mean_absolute_error: 0.0380 - val_mean_squared_error: 0.0042 - val_SSIM: 0.6996 - val_PSNR: 26.1027 - lr: 3.4271e-04
# Epoch 109/200
# 500/500 [==============================] - 240s 480ms/step - loss: 0.0435 - mean_absolute_error: 0.0417 - mean_squared_error: 0.0046 - SSIM: 0.6800 - PSNR: 26.0146 - val_loss: 0.0429 - val_mean_absolute_error: 0.0412 - val_mean_squared_error: 0.0044 - val_SSIM: 0.6938 - val_PSNR: 25.6219 - lr: 3.3243e-04
# Epoch 110/200
# 500/500 [==============================] - 240s 480ms/step - loss: 0.0436 - mean_absolute_error: 0.0419 - mean_squared_error: 0.0046 - SSIM: 0.6768 - PSNR: 25.9871 - val_loss: 0.0390 - val_mean_absolute_error: 0.0373 - val_mean_squared_error: 0.0040 - val_SSIM: 0.7080 - val_PSNR: 26.2384 - lr: 3.2246e-04
# Epoch 111/200
# 500/500 [==============================] - 254s 508ms/step - loss: 0.0436 - mean_absolute_error: 0.0419 - mean_squared_error: 0.0046 - SSIM: 0.6778 - PSNR: 25.9880 - val_loss: 0.0375 - val_mean_absolute_error: 0.0358 - val_mean_squared_error: 0.0041 - val_SSIM: 0.7050 - val_PSNR: 26.5664 - lr: 3.1278e-04
# Epoch 112/200
# 500/500 [==============================] - 228s 455ms/step - loss: 0.0441 - mean_absolute_error: 0.0424 - mean_squared_error: 0.0047 - SSIM: 0.6758 - PSNR: 25.8952 - val_loss: 0.0397 - val_mean_absolute_error: 0.0379 - val_mean_squared_error: 0.0039 - val_SSIM: 0.7133 - val_PSNR: 26.1195 - lr: 3.0340e-04
# Epoch 113/200
# 500/500 [==============================] - 240s 480ms/step - loss: 0.0435 - mean_absolute_error: 0.0418 - mean_squared_error: 0.0046 - SSIM: 0.6790 - PSNR: 25.9878 - val_loss: 0.0395 - val_mean_absolute_error: 0.0378 - val_mean_squared_error: 0.0041 - val_SSIM: 0.7039 - val_PSNR: 26.1938 - lr: 2.9430e-04
# Epoch 114/200
# 500/500 [==============================] - 241s 482ms/step - loss: 0.0434 - mean_absolute_error: 0.0417 - mean_squared_error: 0.0046 - SSIM: 0.6813 - PSNR: 26.0175 - val_loss: 0.0386 - val_mean_absolute_error: 0.0369 - val_mean_squared_error: 0.0040 - val_SSIM: 0.7026 - val_PSNR: 26.2799 - lr: 2.8547e-04
# Epoch 115/200
# 500/500 [==============================] - 240s 480ms/step - loss: 0.0432 - mean_absolute_error: 0.0415 - mean_squared_error: 0.0046 - SSIM: 0.6787 - PSNR: 26.0776 - val_loss: 0.0409 - val_mean_absolute_error: 0.0392 - val_mean_squared_error: 0.0043 - val_SSIM: 0.6995 - val_PSNR: 25.9879 - lr: 2.7690e-04
# Epoch 116/200
# 500/500 [==============================] - 240s 481ms/step - loss: 0.0438 - mean_absolute_error: 0.0421 - mean_squared_error: 0.0047 - SSIM: 0.6773 - PSNR: 25.9471 - val_loss: 0.0377 - val_mean_absolute_error: 0.0361 - val_mean_squared_error: 0.0038 - val_SSIM: 0.7079 - val_PSNR: 26.5805 - lr: 2.6860e-04
# Epoch 117/200
# 500/500 [==============================] - 240s 480ms/step - loss: 0.0432 - mean_absolute_error: 0.0415 - mean_squared_error: 0.0045 - SSIM: 0.6831 - PSNR: 26.0592 - val_loss: 0.0389 - val_mean_absolute_error: 0.0372 - val_mean_squared_error: 0.0040 - val_SSIM: 0.7130 - val_PSNR: 26.2603 - lr: 2.6054e-04
# Epoch 118/200
# 500/500 [==============================] - 241s 482ms/step - loss: 0.0433 - mean_absolute_error: 0.0417 - mean_squared_error: 0.0046 - SSIM: 0.6792 - PSNR: 26.0418 - val_loss: 0.0391 - val_mean_absolute_error: 0.0374 - val_mean_squared_error: 0.0039 - val_SSIM: 0.7089 - val_PSNR: 26.2140 - lr: 2.5272e-04
# Epoch 119/200
# 500/500 [==============================] - 241s 481ms/step - loss: 0.0428 - mean_absolute_error: 0.0411 - mean_squared_error: 0.0045 - SSIM: 0.6832 - PSNR: 26.1332 - val_loss: 0.0399 - val_mean_absolute_error: 0.0382 - val_mean_squared_error: 0.0041 - val_SSIM: 0.7072 - val_PSNR: 26.2126 - lr: 2.4514e-04
# Epoch 120/200
# 500/500 [==============================] - 241s 482ms/step - loss: 0.0434 - mean_absolute_error: 0.0417 - mean_squared_error: 0.0046 - SSIM: 0.6792 - PSNR: 26.0117 - val_loss: 0.0383 - val_mean_absolute_error: 0.0366 - val_mean_squared_error: 0.0040 - val_SSIM: 0.7073 - val_PSNR: 26.3442 - lr: 2.3779e-04
# Epoch 121/200
# 500/500 [==============================] - 240s 481ms/step - loss: 0.0429 - mean_absolute_error: 0.0412 - mean_squared_error: 0.0045 - SSIM: 0.6830 - PSNR: 26.1244 - val_loss: 0.0382 - val_mean_absolute_error: 0.0365 - val_mean_squared_error: 0.0039 - val_SSIM: 0.7058 - val_PSNR: 26.5330 - lr: 2.3065e-04
# Epoch 122/200
# 500/500 [==============================] - 241s 483ms/step - loss: 0.0433 - mean_absolute_error: 0.0417 - mean_squared_error: 0.0046 - SSIM: 0.6786 - PSNR: 26.0059 - val_loss: 0.0380 - val_mean_absolute_error: 0.0364 - val_mean_squared_error: 0.0039 - val_SSIM: 0.7026 - val_PSNR: 26.4492 - lr: 2.2373e-04
# Epoch 123/200
# 500/500 [==============================] - 255s 511ms/step - loss: 0.0431 - mean_absolute_error: 0.0414 - mean_squared_error: 0.0046 - SSIM: 0.6803 - PSNR: 26.1060 - val_loss: 0.0374 - val_mean_absolute_error: 0.0358 - val_mean_squared_error: 0.0038 - val_SSIM: 0.7068 - val_PSNR: 26.5248 - lr: 2.1702e-04
# Epoch 124/200
# 500/500 [==============================] - 227s 454ms/step - loss: 0.0433 - mean_absolute_error: 0.0417 - mean_squared_error: 0.0046 - SSIM: 0.6778 - PSNR: 26.0513 - val_loss: 0.0390 - val_mean_absolute_error: 0.0373 - val_mean_squared_error: 0.0039 - val_SSIM: 0.7061 - val_PSNR: 26.1886 - lr: 2.1051e-04
# Epoch 125/200
# 500/500 [==============================] - 241s 482ms/step - loss: 0.0429 - mean_absolute_error: 0.0413 - mean_squared_error: 0.0045 - SSIM: 0.6843 - PSNR: 26.1316 - val_loss: 0.0375 - val_mean_absolute_error: 0.0359 - val_mean_squared_error: 0.0039 - val_SSIM: 0.7043 - val_PSNR: 26.6178 - lr: 2.0420e-04
# Epoch 126/200
# 500/500 [==============================] - 240s 481ms/step - loss: 0.0429 - mean_absolute_error: 0.0413 - mean_squared_error: 0.0046 - SSIM: 0.6821 - PSNR: 26.1256 - val_loss: 0.0395 - val_mean_absolute_error: 0.0379 - val_mean_squared_error: 0.0041 - val_SSIM: 0.7088 - val_PSNR: 26.1719 - lr: 1.9807e-04
# Epoch 127/200
# 500/500 [==============================] - 241s 483ms/step - loss: 0.0433 - mean_absolute_error: 0.0417 - mean_squared_error: 0.0046 - SSIM: 0.6816 - PSNR: 26.0586 - val_loss: 0.0385 - val_mean_absolute_error: 0.0369 - val_mean_squared_error: 0.0039 - val_SSIM: 0.7100 - val_PSNR: 26.4998 - lr: 1.9213e-04
# Epoch 128/200
# 500/500 [==============================] - 240s 480ms/step - loss: 0.0432 - mean_absolute_error: 0.0416 - mean_squared_error: 0.0046 - SSIM: 0.6822 - PSNR: 26.0834 - val_loss: 0.0377 - val_mean_absolute_error: 0.0361 - val_mean_squared_error: 0.0038 - val_SSIM: 0.7083 - val_PSNR: 26.6017 - lr: 1.8636e-04
# Epoch 129/200
# 500/500 [==============================] - 241s 482ms/step - loss: 0.0429 - mean_absolute_error: 0.0413 - mean_squared_error: 0.
200
# 500/500 [==============================] - 242s 483ms/step - loss: 0.0419 - mean_absolute_error: 0.0405 - mean_squared_error: 0.0045 - SSIM: 0.6872 - PSNR: 26.3075 - val_loss: 0.0350 - val_mean_absolute_error: 0.0336 - val_mean_squared_error: 0.0036 - val_SSIM: 0.7215 - val_PSNR: 27.0911 - lr: 2.2099e-05
# Epoch 199/200
# 500/500 [==============================] - 241s 482ms/step - loss: 0.0415 - mean_absolute_error: 0.0401 - mean_squared_error: 0.0044 - SSIM: 0.6886 - PSNR: 26.4171 - val_loss: 0.0358 - val_mean_absolute_error: 0.0343 - val_mean_squared_error: 0.0037 - val_SSIM: 0.7207 - val_PSNR: 26.8891 - lr: 2.1437e-05
# Epoch 200/200
# 500/500 [==============================] - 242s 483ms/step - loss: 0.0417 - mean_absolute_error: 0.0402 - mean_squared_error: 0.0044 - SSIM: 0.6901 - PSNR: 26.3665 - val_loss: 0.0359 - val_mean_absolute_error: 0.0345 - val_mean_squared_error: 0.0038 - val_SSIM: 0.7186 - val_PSNR: 26.8925 - lr: 2.0793e-05

# %%
from utils.history_utils import show_history
offset = 0
show_history(history, offset)

# %%
from utils.history_utils import show_history
offset = 0
show_history(history, offset)

# %%
from utils.history_utils import show_history
offset = 0
show_history(history, offset)

# %%
from utils.history_utils import show_history
offset = 0
show_history(history, offset)

# %%
from utils.history_utils import show_history
offset = 0
show_history(history, offset)

# %%
from utils.history_utils import show_history
offset = 0
show_history(history, offset)

# %%
from utils.history_utils import show_history
offset = 0
show_history(history, offset)

# %%
from utils.history_utils import show_history
offset = 0
show_history(history, offset)

# %%
from utils.history_utils import show_history
offset = 0
show_history(history, offset)

# %%
from utils.history_utils import show_history
offset = 0
show_history(history, offset)

# %% [markdown]
# ### Save Model and History into Folder

# %%
description = '''
Description:
Fixed data augmentation error.
Simple Autoencoder Compression to 32 x 32 x 32 compressed state: ratio of 1:6
Spatial Dropout p=0 and Prob Aug = 1/2 - removed stateless augmentations/rng wrap (see leg for stateless)
Without Pixel Shuffle (replaced by Conv Transpose)
Added residual blocks, more encoded convs after transmission, and norm back to math operations
Last layer also is a residual block now. With glorot normal initialization and L2 Reg (0.00001).

# Hyperparameters:
INPUT_SHAPE = [None, None, 3]
KERNEL_SIZE = [11, 11]#[7, 7]#[11, 11]#[7, 7]
DILATION_RATE = 2
BATCH_SIZE = 32#16#8
EPOCHS = 200
FILTERS = 4#2#4#8#32
# DROP_PROB = 0.05#0.075#0.05#0.075#0.25#0.1#0.05
KERNEL_REGULARIZER = tf.keras.regularizers.L2(0.00001)#None#tf.keras.regularizers.L2(0.0001)#None#tf.keras.regularizers.L2(0.0001)
KERNEL_INITIALIZER = "glorot_normal"#"orthogonal"#"glorot_normal"#"orthogonal"
DROP_PROB = None#0.1#None#0#0.15
INITIAL_LR = 0.005#0.001
LR_DECAY = 0.97#0.96#0.98#0.95#0.9#0.97#0.95#0.97#0.93
LR_DECAY_START = 10#25
ACTIVATION = 'elu'
AUGMENTATIONS = 20#10#1#10
VAL_AUGMENTATIONS = 10#1#10#5#10#100

Changed lr_schedule to :

def scheduler(epoch, lr):
    if epoch <= LR_DECAY_START:
        return (epoch/LR_DECAY_START)*INITIAL_LR + INITIAL_LR/10000
    elif epoch < 2*LR_DECAY_START:
        return lr
    elif epoch >= 2*LR_DECAY_START:
        return lr*LR_DECAY

with LR_DECAY_START=10, LR_DECAY=0.96, and INITIAL_LR=0.005'''
save_last_x_best_models = 2

if not os.path.exists('./trained_models'):
    os.mkdir('./trained_models')
output_dir = f'trained_models/saved_{model.name.lower()}_gpu{GPU}'

if not os.path.exists(output_dir):
    print(f'Creating New Directory at {output_dir}...')
    os.mkdir(output_dir)
else:
    print('Directory Already Exists...')
    output_dir += '_v1'
    while os.path.exists(output_dir):
        v_num = int(output_dir[-5:].partition('_v')[-1])
        output_dir = output_dir.partition(f'_v{v_num}')[0]
        v_num += 1
        output_dir += f'_v{v_num}'
    print(f'Creating New Directory at {output_dir}...')
    os.mkdir(output_dir)
final_val_loss = history.history['val_loss'][-1]
model.save(os.path.join(output_dir, f'saved_model-epoch_{EPOCHS}-val_loss_{final_val_loss:0.4f}.h5'))
best_model_dir = os.path.join(output_dir, 'best_models')
if not os.path.exists(best_model_dir):
    os.mkdir(best_model_dir)
print('Saving Best Model(s)...')
for i in range(save_last_x_best_models):
    file_list = [file for file in os.listdir(MODEL_DIR) if os.path.isfile(os.path.join(MODEL_DIR, file))]
    filename = sorted(file_list, key=lambda x: int(x.partition('h_')[2].partition('-')[0]))[-1]
    old_path = os.path.join(MODEL_DIR, filename)
    new_path = os.path.join(best_model_dir, filename)
    os.rename(old_path, new_path)
print('Saving History...')
save_history(history, output_dir)
print('Saving Description...')
with open(os.path.join(output_dir, "description.txt"), "a") as f:
    f.write(description)
print('Done!!!')
# Out:
# Directory Already Exists...
# Creating New Directory at trained_models/saved_autoencoder_gpu1_v3...
# Saving Best Model(s)...
# Saving History...
# Saving Description...
# Done!!!

# %% [markdown]
# ### Load Model

# %%
input_dir = 'saved_autoencoder_gpu0'

# %%
#model = tf.keras.models.load_model('./saved_models/saved_model-epoch_08-val_loss_0.01138.h5', compile=False)

# %%
input_dir = os.path.join('./trained_models', input_dir)
best_model_dir = os.path.join(input_dir, 'best_models')
file_list = [file for file in os.listdir(best_model_dir) if os.path.isfile(os.path.join(best_model_dir, file))]
filename = sorted(file_list, key = lambda x : int(x.partition('h_')[2].partition('-')[0]))[-1]
path = os.path.join(best_model_dir, filename)
print('Loading Model...')
print(f'Model Path: {path}')
model = tf.keras.models.load_model(path, compile=False)
print('Done!!!')
# Out:
# Loading Model...
# Model Path: ./trained_models/saved_autoencoder_gpu0/best_models/saved_model-epoch_115-val_loss_0.07574.h5
# Done!!!

# %%
model2.name
# Out:
# 'AutoEncoder'

# %%
model2.summary()
# Out:
# Model: "AutoEncoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  img (InputLayer)            [(None, None, None, 3)]   0
#
#  conv2d (Conv2D)             (None, None, None, 8)     608
#
#  batch_normalization (BatchN  (None, None, None, 8)    32
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, None, None, 8)     1608
#
#  batch_normalization_1 (Batc  (None, None, None, 8)    32
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, None, None, 16)    3216
#
#  batch_normalization_2 (Batc  (None, None, None, 16)   64
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, None, None, 16)    6416
#
#  batch_normalization_3 (Batc  (None, None, None, 16)   64
#  hNormalization)
#
#  conv2d_4 (Conv2D)           (None, None, None, 32)    12832
#
#  batch_normalization_4 (Batc  (None, None, None, 32)   128
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, None, None, 32)    25632
#
#  batch_normalization_5 (Batc  (None, None, None, 32)   128
#  hNormalization)
#
#  conv2d_6 (Conv2D)           (None, None, None, 64)    51264
#
#  batch_normalization_6 (Batc  (None, None, None, 64)   256
#  hNormalization)
#
#  conv2d_7 (Conv2D)           (None, None, None, 64)    102464
#
#  batch_normalization_7 (Batc  (None, None, None, 64)   256
#  hNormalization)
#
#  conv2d_8 (Conv2D)           (None, None, None, 128)   204928
#
#  batch_normalization_8 (Batc  (None, None, None, 128)  512
#  hNormalization)
#
#  conv2d_9 (Conv2D)           (None, None, None, 128)   409728
#
#  batch_normalization_9 (Batc  (None, None, None, 128)  512
#  hNormalization)
#
#  up_sampling2d (UpSampling2D  (None, None, None, 128)  0
#  )
#
#  conv2d_10 (Conv2D)          (None, None, None, 64)    204864
#
#  batch_normalization_10 (Bat  (None, None, None, 64)   256
#  chNormalization)
#
#  conv2d_11 (Conv2D)          (None, None, None, 64)    102464
#
#  batch_normalization_11 (Bat  (None, None, None, 64)   256
#  chNormalization)
#
#  up_sampling2d_1 (UpSampling  (None, None, None, 64)   0
#  2D)
#
#  conv2d_12 (Conv2D)          (None, None, None, 32)    51232
#
#  batch_normalization_12 (Bat  (None, None, None, 32)   128
#  chNormalization)
#
#  conv2d_13 (Conv2D)          (None, None, None, 32)    25632
#
#  batch_normalization_13 (Bat  (None, None, None, 32)   128
#  chNormalization)
#
#  up_sampling2d_2 (UpSampling  (None, None, None, 32)   0
#  2D)
#
#  conv2d_14 (Conv2D)          (None, None, None, 16)    12816
#
#  batch_normalization_14 (Bat  (None, None, None, 16)   64
#  chNormalization)
#
#  conv2d_15 (Conv2D)          (None, None, None, 16)    6416
#
#  batch_normalization_15 (Bat  (None, None, None, 16)   64
#  chNormalization)
#
#  up_sampling2d_3 (UpSampling  (None, None, None, 16)   0
#  2D)
#
#  conv2d_16 (Conv2D)          (None, None, None, 8)     3208
#
#  batch_normalization_16 (Bat  (None, None, None, 8)    32
#  chNormalization)
#
#  conv2d_17 (Conv2D)          (None, None, None, 8)     1608
#
#  batch_normalization_17 (Bat  (None, None, None, 8)    32
#  chNormalization)
#
#  conv2d_18 (Conv2D)          (None, None, None, 3)     27
#
#  batch_normalization_18 (Bat  (None, None, None, 3)    12
#  chNormalization)
#
# =================================================================
# Total params: 1,229,919
# Trainable params: 1,228,441
# Non-trainable params: 1,478
# _________________________________________________________________

# %%
# _,train_img = next(iter(train_ds))
# figsize = (20,20)
# fig = plt.figure(figsize=figsize)
# ax = fig.add_axes([0, 0, 1, 1])
# ax.axis('off')
# ax.imshow(train_img[0,...,0], cmap = 'gray')
# plt.title('Train Image')
# plt.show()

# %%
in_img, gt = next(iter(val_ds))

# %%
in_img.shape
# Out:
# TensorShape([32, 256, 256, 3])

# %%
figsize = (7,7)
fig = plt.figure(figsize=figsize)
ax = fig.add_axes([0, 0, 1, 1])
ax.axis('off')
ax.imshow(in_img[6, ...])
plt.title('Input Image')
plt.show()

# %%
figsize = (7,7)
out_img = model(in_img, training=False)[6, ...]
fig = plt.figure(figsize=figsize)
ax = fig.add_axes([0, 0, 1, 1])
ax.axis('off')
ax.imshow(out_img)
plt.title('Model Output Image')
plt.show()

# %%
np.max(out_img)
# Out:
# 1.0

# %%
tf.keras.utils.plot_model(model, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
# !pip install graphviz
# Out:
# Collecting graphviz
#   Downloading graphviz-0.19.1-py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 1.2 MB/s eta 0:00:01
# Installing collected packages: graphviz
# Successfully installed graphviz-0.19.1

# %%
# !apt install graphviz
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# E: Unable to locate package graphviz
