# %% [markdown]
# ### Import Statements

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import tensorflow_datasets as tfds
import os
import shutil
import imageio
import scipy
import pandas as pd
from functools import partial
from utils.history_utils import save_history

GPU = 0
use_mixed_prec = False

physical_gpus = tf.config.list_physical_devices('GPU')
if physical_gpus:
    try:
        # Disable GPU
        tf.config.set_visible_devices(physical_gpus[GPU:GPU+1], 'GPU')
        visible_gpus = tf.config.get_visible_devices('GPU')
        print("Num Visible Physical GPUs: ", len(physical_gpus),
              "\nNum Visible GPUs Available: ", len(visible_gpus))
        logical_gpus = tf.config.list_logical_devices('GPU')
        print(len(visible_gpus), "Visible GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Virtual devices must be set before GPUs have been initialized
        print(e)

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
MAP_AUTOTUNE = int(os.cpu_count()*3/4)#tf.data.AUTOTUNE#os.cpu_count()#int(os.cpu_count()*3/4)
AUTOTUNE = tf.data.AUTOTUNE
print('Tensorflow version: ' + tf.__version__)
os.environ['NO_GCE_CHECK'] = 'true'

# For Mixed Precision
from tensorflow.keras import mixed_precision
if use_mixed_prec:
    mixed_precision.set_global_policy('mixed_float16')
# Out:
# Num Visible Physical GPUs:  2
# Num Visible GPUs Available:  1
# 1 Visible GPUs, 1 Logical GPUs
# Tensorflow version: 2.8.0

# %% [markdown]
# ## Creating Dataset:

# %%
builder = tfds.ImageFolder('./data', shape=(None, None, 3))

# %%
print(builder.info)
metadata = builder.info
# Out:
# tfds.core.DatasetInfo(
#     name='image_folder',
#     full_name='image_folder/1.0.0',
#     description="""
#     Generic image classification dataset.
#     """,
#     homepage='https://www.tensorflow.org/datasets/catalog/image_folder',
#     data_path='./data',
#     download_size=Unknown size,
#     dataset_size=Unknown size,
#     features=FeaturesDict({
#         'image': Image(shape=(None, None, 3), dtype=tf.uint8),
#         'image/filename': Text(shape=(), dtype=tf.string),
#         'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=1),
#     }),
#     supervised_keys=('image', 'label'),
#     disable_shuffling=False,
#     splits={
#         'train': <SplitInfo num_examples=800, num_shards=1>,
#         'val': <SplitInfo num_examples=100, num_shards=1>,
#     },
#     citation="""""",
# )

# %%
# tf.data.experimental.save(dataset, path)
# new_dataset = tf.data.experimental.load(path)

# %% [markdown]
# ## Creating Input Pipeline

# %%
from utils.downsampling_utils import downsample, downsample_zerofill, downsample_interp
from utils.augmentation_utils import augment, keras_augment, normalize, augment_noise

# %%
(train_ds, val_ds) = builder.as_dataset(split=['train', 'val'], shuffle_files=False)

# %%
NUM_TRAIN = tf.data.experimental.cardinality(train_ds).numpy()
NUM_VAL = tf.data.experimental.cardinality(val_ds).numpy()

# %%
train_ds = train_ds.map(lambda x: x['image'],
                        num_parallel_calls=AUTOTUNE).prefetch(AUTOTUNE)
val_ds = val_ds.map(lambda x: x['image'],
                    num_parallel_calls=AUTOTUNE).prefetch(AUTOTUNE)

# %%
norm_range = [0, 1]
norm_func = partial(normalize, clip=False, out_range=norm_range, if_uint8=True)
train_ds = train_ds.map(norm_func,
                        num_parallel_calls=AUTOTUNE).prefetch(AUTOTUNE)
val_ds = val_ds.map(norm_func,
                    num_parallel_calls=AUTOTUNE).prefetch(AUTOTUNE)

# %%
norm_range = [0, 1]
CROP_SIZE = (256, 256, 3)
INIT_SEED = 7
PROB_OF_AUG = 1/2#1/3 # prob [0,1]
MAX_BRIGHT_SHIFT = 0.1 # in range [0,1]
LOWER_CONTRAST_FACTOR = 0.5#0.75
UPPER_CONTRAST_FACTOR = 1.5#1.25
MAX_HUE_DELTA = 0.05
JPEG_QUALITY_RANGE = [75, 100]
SAT_FACTOR_RANGE = [0.9, 1.1]


GAUSS_NOISE_MEAN = 0
LOWER_GAUSS_NOISE_STD = 0.05
UPPER_GAUSS_NOISE_STD = 0.25

MAX_SHIFT_FRACTION_X_Y = [0.1, 0.1]
MAX_ROTATION_DEG = 10
MAX_ZOOM_FRACTION_X_Y = [0.9, 0.9]
MAX_CHANNEL_INTENSITY_SHIFT = 0.1
SHEAR_INTENSITY = 0.1
FILL_MODE = 'nearest' #'constant'
INTERP_ORD = 3 # No Interp

# %%
main_augment = partial(augment, prob=PROB_OF_AUG,
                       max_shift=MAX_BRIGHT_SHIFT,
                       con_factor_range=[LOWER_CONTRAST_FACTOR, 
                                         UPPER_CONTRAST_FACTOR],
                       max_hue_delta=MAX_HUE_DELTA,
                       jpeg_quality_range=JPEG_QUALITY_RANGE,
                       sat_factor_range=SAT_FACTOR_RANGE,
                       out_range=norm_range,
                       seed=INIT_SEED)
secondary_augment = partial(augment_noise, prob=PROB_OF_AUG,
                            mean=GAUSS_NOISE_MEAN,
                            std_lower=LOWER_GAUSS_NOISE_STD,
                            std_upper=UPPER_GAUSS_NOISE_STD,
                            out_range=norm_range,
                            seed=INIT_SEED)

rand_crop = partial(tf.image.random_crop, size=CROP_SIZE)

lambda_map_func = partial(keras_augment, fill_mode=FILL_MODE,
                          interpolation_order=INTERP_ORD,
                          max_shift_xy=MAX_SHIFT_FRACTION_X_Y,
                          rg=MAX_ROTATION_DEG,
                          zoom_range=MAX_ZOOM_FRACTION_X_Y,
                          intensity_range=MAX_CHANNEL_INTENSITY_SHIFT,
                          shear_intensity=SHEAR_INTENSITY,
                          out_range=norm_range)

lambda_func = lambda x: tf.numpy_function(lambda_map_func, [x], tf.float32)

# %%
train_ds = (
    train_ds
    .cache()
    .map(rand_crop, num_parallel_calls=MAP_AUTOTUNE)
    .prefetch(AUTOTUNE)
    .map(main_augment, num_parallel_calls=MAP_AUTOTUNE)
    .prefetch(AUTOTUNE)
    .map(secondary_augment, num_parallel_calls=MAP_AUTOTUNE)
    .prefetch(AUTOTUNE)
    .map(lambda_func, num_parallel_calls=MAP_AUTOTUNE)
    .prefetch(AUTOTUNE)
)
val_ds = (
    val_ds
    .cache()
    .map(rand_crop, num_parallel_calls=MAP_AUTOTUNE)
    .prefetch(AUTOTUNE)
)

# %%
# img = next(iter(test_ds))
# figsize = (7, 7)
# fig = plt.figure(figsize=figsize)
# ax = fig.add_axes([0, 0, 1, 1])
# ax.axis('off')
# ax.imshow(img)
# plt.title('Test Image')
# plt.show()

# %%
# img = next(iter(test_ds))
# figsize = (7, 7)
# fig = plt.figure(figsize=figsize)
# ax = fig.add_axes([0, 0, 1, 1])
# ax.axis('off')
# ax.imshow(img)
# plt.title('Test Image')
# plt.show()

# %% [markdown]
# ## Define Model Input and Ground Truth

# %%
# def define_in_out(x):
#     return x, x

# %%
from utils.jpeg_utils import jpeg_encode_decode
QUALITY = 10#30

def define_in_out(x):
    return jpeg_encode_decode(x, QUALITY), x 
define_in_out_func = lambda x: tf.numpy_function(define_in_out, [x], [tf.float32, tf.float32])

# %%
train_ds = (
    train_ds
    .map(define_in_out_func, num_parallel_calls=MAP_AUTOTUNE)
    .prefetch(AUTOTUNE)
)
val_ds = (
    val_ds
    .map(define_in_out_func, num_parallel_calls=MAP_AUTOTUNE)
    .prefetch(AUTOTUNE)
)

# %% [markdown]
# ## Model Training:

# %%
# Import Model:
# from models.AutoEncoder import getModel
# from models.AutoEncoder_v2 import getModel
# from models.AutoEncoder_v3 import getModel
# from models.AutoEncoder_v4 import getModel
# from models.AutoEncoder_v5 import getModel
# from models.AutoEncoder_v6 import getModel
# from models.AutoEncoder_v7 import getModel
# from models.AutoEncoder_v8 import getModel
# from models.AutoEncoder_v9 import getModel
# from models.AutoEncoder_v10 import getModel
# from models.AutoEncoder_v11 import getModel
# from models.AutoEncoder_v12 import getModel
# from models.AutoEncoder_v13 import getModel
# from models.AutoEncoder_v14 import getModel
# from models.AutoEncoder_v15 import getModel
# from models.AutoEncoder_v16 import getModel
# from models.AutoEncoder_v17 import getModel
from models.UNet import getModel

# %%
# Hyperparameters:
INPUT_SHAPE = [None, None, 3]
KERNEL_SIZE = [11, 11]#[7, 7]
DILATION_RATE = 2
BATCH_SIZE = 16#8
EPOCHS = 200
FILTERS = 16#4#8#32
# DROP_PROB = 0.05#0.075#0.05#0.075#0.25#0.1#0.05
KERNEL_REGULARIZER = tf.keras.regularizers.L2(0.00001)#None#tf.keras.regularizers.L2(0.0001)#None#tf.keras.regularizers.L2(0.0001)
KERNEL_INITIALIZER = "glorot_normal"#"orthogonal"#"glorot_normal"#"orthogonal"
DROP_PROB = None#0#0.15
INITIAL_LR = 0.005#0.001
LR_DECAY = 0.97#0.96#0.98#0.95#0.9#0.97#0.95#0.97#0.93
LR_DECAY_START = 10#25
ACTIVATION = 'elu'
AUGMENTATIONS = 20#10#1#10
VAL_AUGMENTATIONS = 10#1#10#5#10#100
MODEL_DIR = f'saved_models_{GPU}'
BUFFER_SIZE = 800
UPDATE_INFO_EVERY_X_EPOCHS = 25#47#94#310
delete_previous = True
SAVE_METRIC = 'val_loss'

# %%
model_kwargs = {'filters': FILTERS,
                'kernel_size': KERNEL_SIZE, 
                'activation': ACTIVATION,
                'dilation_rate': DILATION_RATE,
                'prob': DROP_PROB,
                'kernel_initializer': KERNEL_INITIALIZER,
                'kernel_regularizer': KERNEL_REGULARIZER}

# %%
from utils.model_utils import model_loss, PSNR, SSIM

# B1 = 1
# B2 = 0.001
# PIXELWISE_LOSS = tf.keras.losses.MeanAbsoluteError()
# loss_func = model_loss(B1, B2, pixelwise_loss=PIXELWISE_LOSS, name='loss')

loss_func = tf.keras.losses.MeanAbsoluteError()

# %%
train_ds = (
    train_ds
    .prefetch(AUTOTUNE)
    .shuffle(BUFFER_SIZE)
    .batch(BATCH_SIZE)
    .repeat()
    .prefetch(AUTOTUNE)
)
val_ds = (
    val_ds
    .prefetch(AUTOTUNE)
    .shuffle(BUFFER_SIZE//4)# was //8
    .batch(BATCH_SIZE)
    .repeat()
    .prefetch(AUTOTUNE)
)

# %%
def scheduler(epoch, lr):
    if epoch <= LR_DECAY_START:
        return (epoch/LR_DECAY_START)*INITIAL_LR + INITIAL_LR/10000
    elif epoch < 2*LR_DECAY_START:
        return lr
    elif epoch >= 2*LR_DECAY_START:
        return lr*LR_DECAY

# %%
model = getModel(input_shape=INPUT_SHAPE, **model_kwargs)

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=INITIAL_LR)#, amsgrad=True)#, clipvalue=10)
if use_mixed_prec:
    optimizer = mixed_precision.LossScaleOptimizer(optimizer)
model.compile(optimizer=optimizer,  # pick an optimizer
              loss=loss_func,
              steps_per_execution=((AUGMENTATIONS) * np.ceil(NUM_TRAIN/BATCH_SIZE)) // UPDATE_INFO_EVERY_X_EPOCHS,
              metrics=['mean_absolute_error', 'mean_squared_error', SSIM, PSNR])

# %%
model.summary()
# Out:
# Model: "UNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  img (InputLayer)               [(None, None, None,  0           []
#                                  3)]
#
#  conv2d (Conv2D)                (None, None, None,   5824        ['img[0][0]']
#                                 16)
#
#  batch_normalization (BatchNorm  (None, None, None,   64         ['conv2d[0][0]']
#  alization)                     16)
#
#  conv2d_1 (Conv2D)              (None, None, None,   30992       ['batch_normalization[0][0]']
#                                 16)
#
#  conv2d_2 (Conv2D)              (None, None, None,   64          ['img[0][0]']
#                                 16)
#
#  batch_normalization_1 (BatchNo  (None, None, None,   64         ['conv2d_1[0][0]']
#  rmalization)                   16)
#
#  batch_normalization_2 (BatchNo  (None, None, None,   64         ['conv2d_2[0][0]']
#  rmalization)                   16)
#
#  add (Add)                      (None, None, None,   0           ['batch_normalization_1[0][0]',
#                                 16)                               'batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, None, None,   61984       ['add[0][0]']
#                                 32)
#
#  batch_normalization_3 (BatchNo  (None, None, None,   128        ['conv2d_3[0][0]']
#  rmalization)                   32)
#
#  conv2d_4 (Conv2D)              (None, None, None,   123936      ['batch_normalization_3[0][0]']
#                                 32)
#
#  batch_normalization_4 (BatchNo  (None, None, None,   128        ['conv2d_4[0][0]']
#  rmalization)                   32)
#
#  conv2d_5 (Conv2D)              (None, None, None,   123936      ['batch_normalization_4[0][0]']
#                                 32)
#
#  conv2d_6 (Conv2D)              (None, None, None,   1056        ['batch_normalization_3[0][0]']
#                                 32)
#
#  batch_normalization_5 (BatchNo  (None, None, None,   128        ['conv2d_5[0][0]']
#  rmalization)                   32)
#
#  batch_normalization_6 (BatchNo  (None, None, None,   128        ['conv2d_6[0][0]']
#  rmalization)                   32)
#
#  add_1 (Add)                    (None, None, None,   0           ['batch_normalization_5[0][0]',
#                                 32)                               'batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, None, None,   247872      ['add_1[0][0]']
#                                 64)
#
#  batch_normalization_7 (BatchNo  (None, None, None,   256        ['conv2d_7[0][0]']
#  rmalization)                   64)
#
#  conv2d_8 (Conv2D)              (None, None, None,   495680      ['batch_normalization_7[0][0]']
#                                 64)
#
#  batch_normalization_8 (BatchNo  (None, None, None,   256        ['conv2d_8[0][0]']
#  rmalization)                   64)
#
#  conv2d_9 (Conv2D)              (None, None, None,   495680      ['batch_normalization_8[0][0]']
#                                 64)
#
#  conv2d_10 (Conv2D)             (None, None, None,   4160        ['batch_normalization_7[0][0]']
#                                 64)
#
#  batch_normalization_9 (BatchNo  (None, None, None,   256        ['conv2d_9[0][0]']
#  rmalization)                   64)
#
#  batch_normalization_10 (BatchN  (None, None, None,   256        ['conv2d_10[0][0]']
#  ormalization)                  64)
#
#  add_2 (Add)                    (None, None, None,   0           ['batch_normalization_9[0][0]',
#                                 64)                               'batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, None, None,   991360      ['add_2[0][0]']
#                                 128)
#
#  batch_normalization_11 (BatchN  (None, None, None,   512        ['conv2d_11[0][0]']
#  ormalization)                  128)
#
#  conv2d_12 (Conv2D)             (None, None, None,   1982592     ['batch_normalization_11[0][0]']
#                                 128)
#
#  batch_normalization_12 (BatchN  (None, None, None,   512        ['conv2d_12[0][0]']
#  ormalization)                  128)
#
#  conv2d_13 (Conv2D)             (None, None, None,   1982592     ['batch_normalization_12[0][0]']
#                                 128)
#
#  conv2d_14 (Conv2D)             (None, None, None,   16512       ['batch_normalization_11[0][0]']
#                                 128)
#
#  batch_normalization_13 (BatchN  (None, None, None,   512        ['conv2d_13[0][0]']
#  ormalization)                  128)
#
#  batch_normalization_14 (BatchN  (None, None, None,   512        ['conv2d_14[0][0]']
#  ormalization)                  128)
#
#  add_3 (Add)                    (None, None, None,   0           ['batch_normalization_13[0][0]',
#                                 128)                              'batch_normalization_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, None, None,   3965184     ['add_3[0][0]']
#                                 256)
#
#  batch_normalization_15 (BatchN  (None, None, None,   1024       ['conv2d_15[0][0]']
#  ormalization)                  256)
#
#  conv2d_16 (Conv2D)             (None, None, None,   7930112     ['batch_normalization_15[0][0]']
#                                 256)
#
#  batch_normalization_16 (BatchN  (None, None, None,   1024       ['conv2d_16[0][0]']
#  ormalization)                  256)
#
#  conv2d_17 (Conv2D)             (None, None, None,   7930112     ['batch_normalization_16[0][0]']
#                                 256)
#
#  conv2d_18 (Conv2D)             (None, None, None,   65792       ['batch_normalization_15[0][0]']
#                                 256)
#
#  batch_normalization_17 (BatchN  (None, None, None,   1024       ['conv2d_17[0][0]']
#  ormalization)                  256)
#
#  batch_normalization_18 (BatchN  (None, None, None,   1024       ['conv2d_18[0][0]']
#  ormalization)                  256)
#
#  add_4 (Add)                    (None, None, None,   0           ['batch_normalization_17[0][0]',
#                                 256)                              'batch_normalization_18[0][0]']
#
#  conv2d_19 (Conv2D)             (None, None, None,   7930112     ['add_4[0][0]']
#                                 256)
#
#  batch_normalization_19 (BatchN  (None, None, None,   1024       ['conv2d_19[0][0]']
#  ormalization)                  256)
#
#  conv2d_20 (Conv2D)             (None, None, None,   7930112     ['batch_normalization_19[0][0]']
#                                 256)
#
#  conv2d_21 (Conv2D)             (None, None, None,   65792       ['add_4[0][0]']
#                                 256)
#
#  batch_normalization_20 (BatchN  (None, None, None,   1024       ['conv2d_20[0][0]']
#  ormalization)                  256)
#
#  batch_normalization_21 (BatchN  (None, None, None,   1024       ['conv2d_21[0][0]']
#  ormalization)                  256)
#
#  conv2d_22 (Conv2D)             (None, None, None,   65792       ['batch_normalization_15[0][0]']
#                                 256)
#
#  add_5 (Add)                    (None, None, None,   0           ['batch_normalization_20[0][0]',
#                                 256)                              'batch_normalization_21[0][0]']
#
#  batch_normalization_22 (BatchN  (None, None, None,   1024       ['conv2d_22[0][0]']
#  ormalization)                  256)
#
#  add_6 (Add)                    (None, None, None,   0           ['add_5[0][0]',
#                                 256)                              'batch_normalization_22[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, None, None,   2097280    ['add_6[0][0]']
#  ose)                           128)
#
#  batch_normalization_23 (BatchN  (None, None, None,   512        ['conv2d_transpose[0][0]']
#  ormalization)                  128)
#
#  concatenate (Concatenate)      (None, None, None,   0           ['batch_normalization_23[0][0]',
#                                 256)                              'add_3[0][0]']
#
#  conv2d_23 (Conv2D)             (None, None, None,   3965056     ['concatenate[0][0]']
#                                 128)
#
#  batch_normalization_24 (BatchN  (None, None, None,   512        ['conv2d_23[0][0]']
#  ormalization)                  128)
#
#  conv2d_24 (Conv2D)             (None, None, None,   1982592     ['batch_normalization_24[0][0]']
#                                 128)
#
#  conv2d_25 (Conv2D)             (None, None, None,   32896       ['concatenate[0][0]']
#                                 128)
#
#  batch_normalization_25 (BatchN  (None, None, None,   512        ['conv2d_24[0][0]']
#  ormalization)                  128)
#
#  batch_normalization_26 (BatchN  (None, None, None,   512        ['conv2d_25[0][0]']
#  ormalization)                  128)
#
#  add_7 (Add)                    (None, None, None,   0           ['batch_normalization_25[0][0]',
#                                 128)                              'batch_normalization_26[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, None, None,   524352     ['add_7[0][0]']
#  spose)                         64)
#
#  batch_normalization_27 (BatchN  (None, None, None,   256        ['conv2d_transpose_1[0][0]']
#  ormalization)                  64)
#
#  concatenate_1 (Concatenate)    (None, None, None,   0           ['batch_normalization_27[0][0]',
#                                 128)                              'add_2[0][0]']
#
#  conv2d_26 (Conv2D)             (None, None, None,   991296      ['concatenate_1[0][0]']
#                                 64)
#
#  batch_normalization_28 (BatchN  (None, None, None,   256        ['conv2d_26[0][0]']
#  ormalization)                  64)
#
#  conv2d_27 (Conv2D)             (None, None, None,   495680      ['batch_normalization_28[0][0]']
#                                 64)
#
#  conv2d_28 (Conv2D)             (None, None, None,   8256        ['concatenate_1[0][0]']
#                                 64)
#
#  batch_normalization_29 (BatchN  (None, None, None,   256        ['conv2d_27[0][0]']
#  ormalization)                  64)
#
#  batch_normalization_30 (BatchN  (None, None, None,   256        ['conv2d_28[0][0]']
#  ormalization)                  64)
#
#  add_8 (Add)                    (None, None, None,   0           ['batch_normalization_29[0][0]',
#                                 64)                               'batch_normalization_30[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, None, None,   131104     ['add_8[0][0]']
#  spose)                         32)
#
#  batch_normalization_31 (BatchN  (None, None, None,   128        ['conv2d_transpose_2[0][0]']
#  ormalization)                  32)
#
#  concatenate_2 (Concatenate)    (None, None, None,   0           ['batch_normalization_31[0][0]',
#                                 64)                               'add_1[0][0]']
#
#  conv2d_29 (Conv2D)             (None, None, None,   247840      ['concatenate_2[0][0]']
#                                 32)
#
#  batch_normalization_32 (BatchN  (None, None, None,   128        ['conv2d_29[0][0]']
#  ormalization)                  32)
#
#  conv2d_30 (Conv2D)             (None, None, None,   123936      ['batch_normalization_32[0][0]']
#                                 32)
#
#  conv2d_31 (Conv2D)             (None, None, None,   2080        ['concatenate_2[0][0]']
#                                 32)
#
#  batch_normalization_33 (BatchN  (None, None, None,   128        ['conv2d_30[0][0]']
#  ormalization)                  32)
#
#  batch_normalization_34 (BatchN  (None, None, None,   128        ['conv2d_31[0][0]']
#  ormalization)                  32)
#
#  add_9 (Add)                    (None, None, None,   0           ['batch_normalization_33[0][0]',
#                                 32)                               'batch_normalization_34[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, None, None,   32784      ['add_9[0][0]']
#  spose)                         16)
#
#  batch_normalization_35 (BatchN  (None, None, None,   64         ['conv2d_transpose_3[0][0]']
#  ormalization)                  16)
#
#  concatenate_3 (Concatenate)    (None, None, None,   0           ['batch_normalization_35[0][0]',
#                                 32)                               'add[0][0]']
#
#  conv2d_32 (Conv2D)             (None, None, None,   61968       ['concatenate_3[0][0]']
#                                 16)
#
#  batch_normalization_36 (BatchN  (None, None, None,   64         ['conv2d_32[0][0]']
#  ormalization)                  16)
#
#  conv2d_33 (Conv2D)             (None, None, None,   30992       ['batch_normalization_36[0][0]']
#                                 16)
#
#  conv2d_34 (Conv2D)             (None, None, None,   528         ['concatenate_3[0][0]']
#                                 16)
#
#  batch_normalization_37 (BatchN  (None, None, None,   64         ['conv2d_33[0][0]']
#  ormalization)                  16)
#
#  batch_normalization_38 (BatchN  (None, None, None,   64         ['conv2d_34[0][0]']
#  ormalization)                  16)
#
#  add_10 (Add)                   (None, None, None,   0           ['batch_normalization_37[0][0]',
#                                 16)                               'batch_normalization_38[0][0]']
#
#  conv2d_35 (Conv2D)             (None, None, None,   17          ['add_10[0][0]']
#                                 1)
#
#  batch_normalization_39 (BatchN  (None, None, None,   4          ['conv2d_35[0][0]']
#  ormalization)                  1)
#
#  add_11 (Add)                   (None, None, None,   0           ['batch_normalization_39[0][0]',
#                                 3)                                'img[0][0]']
#
# ==================================================================================================
# Total params: 53,191,717
# Trainable params: 53,183,811
# Non-trainable params: 7,906
# __________________________________________________________________________________________________

# %%
if not os.path.exists(MODEL_DIR):
    os.mkdir(MODEL_DIR)
elif delete_previous:
    shutil.rmtree(MODEL_DIR)
    os.mkdir(MODEL_DIR)

lr_schedule = tf.keras.callbacks.LearningRateScheduler(scheduler)
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=os.path.join(MODEL_DIR, 
                                                                            'saved_model-epoch_{epoch:02d}-' + 
                                                                            SAVE_METRIC + '_{' + 
                                                                            SAVE_METRIC + ':.5f}.h5'),
                                                      monitor=SAVE_METRIC,
                                                      verbose=0,
                                                      save_best_only=True,
                                                      save_weights_only=False,
                                                      mode='min',
                                                      save_freq='epoch')

my_callbacks = [model_checkpoint, lr_schedule]

history = model.fit(train_ds,
                    steps_per_epoch=AUGMENTATIONS*np.ceil(NUM_TRAIN/BATCH_SIZE),
                    epochs=EPOCHS,
                    callbacks=my_callbacks,
                    validation_data=val_ds,
                    validation_steps=VAL_AUGMENTATIONS*np.ceil(NUM_VAL/BATCH_SIZE),
                    max_queue_size=10*AUGMENTATIONS*np.ceil(NUM_TRAIN/BATCH_SIZE))
# Out:
# Epoch 1/200
# 1000/1000 [==============================] - 518s 518ms/step - loss: 0.5900 - mean_absolute_error: 0.5499 - mean_squared_error: 1.0020 - SSIM: 0.0245 - PSNR: 3.0715 - val_loss: 0.4609 - val_mean_absolute_error: 0.4208 - val_mean_squared_error: 1.7106 - val_SSIM: 0.0521 - val_PSNR: 5.7587 - lr: 5.0000e-07
# Epoch 2/200
# 1000/1000 [==============================] - 443s 443ms/step - loss: 0.1048 - mean_absolute_error: 0.0696 - mean_squared_error: 0.9419 - SSIM: 0.6665 - PSNR: 22.8668 - val_loss: 0.1228 - val_mean_absolute_error: 0.0898 - val_mean_squared_error: 3.0435 - val_SSIM: 0.6699 - val_PSNR: 21.0292 - lr: 5.0050e-04
# Epoch 3/200
# 1000/1000 [==============================] - 440s 440ms/step - loss: 0.0794 - mean_absolute_error: 0.0471 - mean_squared_error: 0.8300 - SSIM: 0.7228 - PSNR: 23.9459 - val_loss: 0.0582 - val_mean_absolute_error: 0.0348 - val_mean_squared_error: 0.0024 - val_SSIM: 0.7719 - val_PSNR: 27.1870 - lr: 0.0010
# Epoch 4/200
# 1000/1000 [==============================] - 421s 421ms/step - loss: 0.1043 - mean_absolute_error: 0.0569 - mean_squared_error: 0.4752 - SSIM: 0.6985 - PSNR: 22.3203 - val_loss: 0.0697 - val_mean_absolute_error: 0.0350 - val_mean_squared_error: 0.0045 - val_SSIM: 0.7471 - val_PSNR: 26.8032 - lr: 0.0015
# Epoch 5/200
# 1000/1000 [==============================] - 456s 456ms/step - loss: 0.0684 - mean_absolute_error: 0.0386 - mean_squared_error: 0.2058 - SSIM: 0.7425 - PSNR: 24.5036 - val_loss: 0.0514 - val_mean_absolute_error: 0.0344 - val_mean_squared_error: 0.0100 - val_SSIM: 0.7671 - val_PSNR: 25.8855 - lr: 0.0020
# Epoch 6/200
# 1000/1000 [==============================] - 443s 443ms/step - loss: 0.0528 - mean_absolute_error: 0.0375 - mean_squared_error: 0.0546 - SSIM: 0.7461 - PSNR: 24.4109 - val_loss: 0.0428 - val_mean_absolute_error: 0.0338 - val_mean_squared_error: 0.0299 - val_SSIM: 0.7716 - val_PSNR: 24.6186 - lr: 0.0025
# Epoch 7/200
# 1000/1000 [==============================] - 442s 442ms/step - loss: 0.0421 - mean_absolute_error: 0.0363 - mean_squared_error: 0.0111 - SSIM: 0.7505 - PSNR: 25.8498 - val_loss: 0.0377 - val_mean_absolute_error: 0.0334 - val_mean_squared_error: 0.0024 - val_SSIM: 0.7770 - val_PSNR: 27.4880 - lr: 0.0030
# Epoch 8/200
# 1000/1000 [==============================] - 442s 442ms/step - loss: 0.0592 - mean_absolute_error: 0.0361 - mean_squared_error: 0.0044 - SSIM: 0.7513 - PSNR: 26.7028 - val_loss: 0.0354 - val_mean_absolute_error: 0.0334 - val_mean_squared_error: 0.0023 - val_SSIM: 0.7693 - val_PSNR: 27.5073 - lr: 0.0035
# Epoch 9/200
# 1000/1000 [==============================] - 420s 420ms/step - loss: 0.
# %%
from utils.history_utils import show_history
offset = 0
show_history(history, offset)

# %%
from utils.history_utils import show_history
offset = 0
show_history(history, offset)

# %%
from utils.history_utils import show_history
offset = 0
show_history(history, offset)

# %%
from utils.history_utils import show_history
offset = 0
show_history(history, offset)

# %%
from utils.history_utils import show_history
offset = 0
show_history(history, offset)

# %%
from utils.history_utils import show_history
offset = 0
show_history(history, offset)

# %%
from utils.history_utils import show_history
offset = 0
show_history(history, offset)

# %%
from utils.history_utils import show_history
offset = 0
show_history(history, offset)

# %%
from utils.history_utils import show_history
offset = 0
show_history(history, offset)

# %%
from utils.history_utils import show_history
offset = 0
show_history(history, offset)

# %%
from utils.history_utils import show_history
offset = 0
show_history(history, offset)

# %% [markdown]
# ### Save Model and History into Folder

# %%
description = '''
Description:
Fixed Zoom fraction augmentation error (too much zoom)
Simple UNet JPEG artifact removal (compression ratio tbd) - Q=10
Spatial Dropout p=0 and Prob Aug = 1/2 - removed stateless augmentations/rng wrap (see leg for stateless)
Without Pixel Shuffle (replaced by Conv Transpose)
Added residual blocks, more encoded convs after transmission, and norm back to math operations
Last layer also is a residual block now. Res block now only has 2 convs.

# Hyperparameters:
INPUT_SHAPE = [None, None, 3]
KERNEL_SIZE = [11, 11]#[7, 7]
DILATION_RATE = 2
BATCH_SIZE = 16#8
EPOCHS = 200
FILTERS = 16#4#8#32
# DROP_PROB = 0.05#0.075#0.05#0.075#0.25#0.1#0.05
KERNEL_REGULARIZER = tf.keras.regularizers.L2(0.00001)#None#tf.keras.regularizers.L2(0.0001)#None#tf.keras.regularizers.L2(0.0001)
KERNEL_INITIALIZER = "glorot_normal"#"orthogonal"#"glorot_normal"#"orthogonal"
DROP_PROB = None#0#0.15
INITIAL_LR = 0.005#0.001
LR_DECAY = 0.97#0.96#0.98#0.95#0.9#0.97#0.95#0.97#0.93
LR_DECAY_START = 10#25
ACTIVATION = 'elu'
AUGMENTATIONS = 20#10#1#10
VAL_AUGMENTATIONS = 10#1#10#5#10#100

Changed lr_schedule to :

def scheduler(epoch, lr):
    if epoch <= LR_DECAY_START:
        return (epoch/LR_DECAY_START)*INITIAL_LR + INITIAL_LR/10000
    elif epoch < 2*LR_DECAY_START:
        return lr
    elif epoch >= 2*LR_DECAY_START:
        return lr*LR_DECAY

with LR_DECAY_START=10, LR_DECAY=0.96, and INITIAL_LR=0.005'''
save_last_x_best_models = 2

if not os.path.exists('./trained_models'):
    os.mkdir('./trained_models')
output_dir = f'trained_models/saved_{model.name.lower()}_gpu{GPU}'

if not os.path.exists(output_dir):
    print(f'Creating New Directory at {output_dir}...')
    os.mkdir(output_dir)
else:
    print('Directory Already Exists...')
    output_dir += '_v1'
    while os.path.exists(output_dir):
        v_num = int(output_dir[-5:].partition('_v')[-1])
        output_dir = output_dir.partition(f'_v{v_num}')[0]
        v_num += 1
        output_dir += f'_v{v_num}'
    print(f'Creating New Directory at {output_dir}...')
    os.mkdir(output_dir)
final_val_loss = history.history['val_loss'][-1]
model.save(os.path.join(output_dir, f'saved_model-epoch_{EPOCHS}-val_loss_{final_val_loss:0.4f}.h5'))
best_model_dir = os.path.join(output_dir, 'best_models')
if not os.path.exists(best_model_dir):
    os.mkdir(best_model_dir)
print('Saving Best Model(s)...')
for i in range(save_last_x_best_models):
    file_list = [file for file in os.listdir(MODEL_DIR) if os.path.isfile(os.path.join(MODEL_DIR, file))]
    filename = sorted(file_list, key=lambda x: int(x.partition('h_')[2].partition('-')[0]))[-1]
    old_path = os.path.join(MODEL_DIR, filename)
    new_path = os.path.join(best_model_dir, filename)
    os.rename(old_path, new_path)
print('Saving History...')
save_history(history, output_dir)
print('Saving Description...')
with open(os.path.join(output_dir, "description.txt"), "a") as f:
    f.write(description)
print('Done!!!')
# Out:
# Directory Already Exists...
# Creating New Directory at trained_models/saved_unet_gpu0_v1...
# Saving Best Model(s)...
# Saving History...
# Saving Description...
# Done!!!

# %% [markdown]
# ### Load Model

# %%
input_dir = 'saved_autoencoder_gpu0'

# %%
#model = tf.keras.models.load_model('./saved_models/saved_model-epoch_08-val_loss_0.01138.h5', compile=False)

# %%
input_dir = os.path.join('./trained_models', input_dir)
best_model_dir = os.path.join(input_dir, 'best_models')
file_list = [file for file in os.listdir(best_model_dir) if os.path.isfile(os.path.join(best_model_dir, file))]
filename = sorted(file_list, key = lambda x : int(x.partition('h_')[2].partition('-')[0]))[-1]
path = os.path.join(best_model_dir, filename)
print('Loading Model...')
print(f'Model Path: {path}')
model = tf.keras.models.load_model(path, compile=False)
print('Done!!!')

# %%
model2.name

# %%
model.summary()

# %%
# _,train_img = next(iter(train_ds))
# figsize = (20,20)
# fig = plt.figure(figsize=figsize)
# ax = fig.add_axes([0, 0, 1, 1])
# ax.axis('off')
# ax.imshow(train_img[0,...,0], cmap = 'gray')
# plt.title('Train Image')
# plt.show()

# %%
in_img, gt = next(iter(train_ds))

# %%
in_img.shape
# Out:
# TensorShape([16, 256, 256, 3])

# %%
figsize = (7,7)
fig = plt.figure(figsize=figsize)
ax = fig.add_axes([0, 0, 1, 1])
ax.axis('off')
ax.imshow(in_img[6, ...])
plt.title('Input Image')
plt.show()

# %%
figsize = (7,7)
out_img = model(in_img, training=False)[6, ...]
fig = plt.figure(figsize=figsize)
ax = fig.add_axes([0, 0, 1, 1])
ax.axis('off')
ax.imshow(out_img)
plt.title('Model Output Image')
plt.show()

# %%
in_img, gt = next(iter(val_ds))

# %%
in_img.shape
# Out:
# TensorShape([16, 256, 256, 3])

# %%
figsize = (7,7)
fig = plt.figure(figsize=figsize)
ax = fig.add_axes([0, 0, 1, 1])
ax.axis('off')
ax.imshow(in_img[6, ...])
plt.title('Input Image')
plt.show()
figsize = (7,7)
fig = plt.figure(figsize=figsize)
ax = fig.add_axes([0, 0, 1, 1])
ax.axis('off')
ax.imshow(gt[6, ...])
plt.title('GT Image')
plt.show()

# %%
figsize = (7,7)
out_img = model(in_img, training=False)[6, ...]
fig = plt.figure(figsize=figsize)
ax = fig.add_axes([0, 0, 1, 1])
ax.axis('off')
ax.imshow(out_img)
plt.title('Model Output Image')
plt.show()

# %%
np.max(out_img)

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
# !pip install graphviz

# %%
# !apt install graphviz

# %%
tf.math.reduce_mean(SSIM(gt[6, ...], in_img[6, ...]))
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.8019302>

# %%
tf.math.reduce_mean(SSIM(gt[6, ...], out_img))
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.81113476>

# %%
tf.math.reduce_mean(tf.image.ssim_multiscale(gt[6, ...], out_img, 1))
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.96352744>

# %%
tf.math.reduce_mean(tf.image.ssim_multiscale(gt[6, ...], in_img[6, ...], 1))
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.9616453>

# %%
from utils.model_utils import model_loss
print(model_loss()(gt, in_img))
print(loss_func(gt, in_img))
# Out:
# tf.Tensor(0.018567657, shape=(), dtype=float32)
# tf.Tensor(0.01847284, shape=(), dtype=float32)
