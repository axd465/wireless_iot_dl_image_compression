# %% [markdown]
# ### Import Statements

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import tensorflow_datasets as tfds
import os
import shutil
import imageio
import scipy
import pandas as pd
from functools import partial
from utils.history_utils import save_history

GPU = 0
use_mixed_prec = False

physical_gpus = tf.config.list_physical_devices('GPU')
if physical_gpus:
    try:
        # Disable GPU
        tf.config.set_visible_devices(physical_gpus[GPU:GPU+1], 'GPU')
        visible_gpus = tf.config.get_visible_devices('GPU')
        print("Num Visible Physical GPUs: ", len(physical_gpus),
              "\nNum Visible GPUs Available: ", len(visible_gpus))
        logical_gpus = tf.config.list_logical_devices('GPU')
        print(len(visible_gpus), "Visible GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Virtual devices must be set before GPUs have been initialized
        print(e)

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
MAP_AUTOTUNE = int(os.cpu_count()*3/4)#tf.data.AUTOTUNE#os.cpu_count()#int(os.cpu_count()*3/4)
AUTOTUNE = tf.data.AUTOTUNE
print('Tensorflow version: ' + tf.__version__)
os.environ['NO_GCE_CHECK'] = 'true'

# For Mixed Precision
from tensorflow.keras import mixed_precision
if use_mixed_prec:
    mixed_precision.set_global_policy('mixed_float16')
# Out:
# Num Visible Physical GPUs:  2
# Num Visible GPUs Available:  1
# 1 Visible GPUs, 1 Logical GPUs
# Tensorflow version: 2.8.0

# %% [markdown]
# ## Creating Dataset:

# %%
builder = tfds.ImageFolder('./data', shape=(None, None, 3))

# %%
print(builder.info)
metadata = builder.info
# Out:
# tfds.core.DatasetInfo(
#     name='image_folder',
#     full_name='image_folder/1.0.0',
#     description="""
#     Generic image classification dataset.
#     """,
#     homepage='https://www.tensorflow.org/datasets/catalog/image_folder',
#     data_path='./data',
#     download_size=Unknown size,
#     dataset_size=Unknown size,
#     features=FeaturesDict({
#         'image': Image(shape=(None, None, 3), dtype=tf.uint8),
#         'image/filename': Text(shape=(), dtype=tf.string),
#         'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=1),
#     }),
#     supervised_keys=('image', 'label'),
#     disable_shuffling=False,
#     splits={
#         'train': <SplitInfo num_examples=800, num_shards=1>,
#         'val': <SplitInfo num_examples=100, num_shards=1>,
#     },
#     citation="""""",
# )

# %%
# tf.data.experimental.save(dataset, path)
# new_dataset = tf.data.experimental.load(path)

# %% [markdown]
# ## Creating Input Pipeline

# %%
from utils.downsampling_utils import downsample, downsample_zerofill, downsample_interp
from utils.augmentation_utils import augment, keras_augment, normalize, augment_noise

# %%
(train_ds, val_ds) = builder.as_dataset(split=['train', 'val'], shuffle_files=False)

# %%
NUM_TRAIN = tf.data.experimental.cardinality(train_ds).numpy()
NUM_VAL = tf.data.experimental.cardinality(val_ds).numpy()

# %%
train_ds = train_ds.map(lambda x: x['image'],
                        num_parallel_calls=AUTOTUNE).prefetch(AUTOTUNE)
val_ds = val_ds.map(lambda x: x['image'],
                    num_parallel_calls=AUTOTUNE).prefetch(AUTOTUNE)

# %%
norm_range = [0, 1]
norm_func = partial(normalize, clip=False, out_range=norm_range, if_uint8=True)
train_ds = train_ds.map(norm_func,
                        num_parallel_calls=AUTOTUNE).prefetch(AUTOTUNE)
val_ds = val_ds.map(norm_func,
                    num_parallel_calls=AUTOTUNE).prefetch(AUTOTUNE)

# %%
norm_range = [0, 1]
CROP_SIZE = (256, 256, 3)
INIT_SEED = 7
PROB_OF_AUG = 1/2#1/3 # prob [0,1]
MAX_BRIGHT_SHIFT = 0.1 # in range [0,1]
LOWER_CONTRAST_FACTOR = 0.5#0.75
UPPER_CONTRAST_FACTOR = 1.5#1.25
MAX_HUE_DELTA = 0.05
JPEG_QUALITY_RANGE = [75, 100]
SAT_FACTOR_RANGE = [0.9, 1.1]


GAUSS_NOISE_MEAN = 0
LOWER_GAUSS_NOISE_STD = 0.05
UPPER_GAUSS_NOISE_STD = 0.25

MAX_SHIFT_FRACTION_X_Y = [0.1, 0.1]
MAX_ROTATION_DEG = 10
MAX_ZOOM_FRACTION_X_Y = [0.9, 0.9]
MAX_CHANNEL_INTENSITY_SHIFT = 0.1
SHEAR_INTENSITY = 0.1
FILL_MODE = 'nearest' #'constant'
INTERP_ORD = 3 # No Interp

# %%
main_augment = partial(augment, prob=PROB_OF_AUG,
                       max_shift=MAX_BRIGHT_SHIFT,
                       con_factor_range=[LOWER_CONTRAST_FACTOR, 
                                         UPPER_CONTRAST_FACTOR],
                       max_hue_delta=MAX_HUE_DELTA,
                       jpeg_quality_range=JPEG_QUALITY_RANGE,
                       sat_factor_range=SAT_FACTOR_RANGE,
                       out_range=norm_range,
                       seed=INIT_SEED)
secondary_augment = partial(augment_noise, prob=PROB_OF_AUG,
                            mean=GAUSS_NOISE_MEAN,
                            std_lower=LOWER_GAUSS_NOISE_STD,
                            std_upper=UPPER_GAUSS_NOISE_STD,
                            out_range=norm_range,
                            seed=INIT_SEED)

rand_crop = partial(tf.image.random_crop, size=CROP_SIZE)

lambda_map_func = partial(keras_augment, fill_mode=FILL_MODE,
                          interpolation_order=INTERP_ORD,
                          max_shift_xy=MAX_SHIFT_FRACTION_X_Y,
                          rg=MAX_ROTATION_DEG,
                          zoom_range=MAX_ZOOM_FRACTION_X_Y,
                          intensity_range=MAX_CHANNEL_INTENSITY_SHIFT,
                          shear_intensity=SHEAR_INTENSITY,
                          out_range=norm_range)

lambda_func = lambda x: tf.numpy_function(lambda_map_func, [x], tf.float32)

# %%
train_ds = (
    train_ds
    .cache()
    .map(rand_crop, num_parallel_calls=MAP_AUTOTUNE)
    .prefetch(AUTOTUNE)
    .map(main_augment, num_parallel_calls=MAP_AUTOTUNE)
    .prefetch(AUTOTUNE)
    .map(secondary_augment, num_parallel_calls=MAP_AUTOTUNE)
    .prefetch(AUTOTUNE)
    .map(lambda_func, num_parallel_calls=MAP_AUTOTUNE)
    .prefetch(AUTOTUNE)
)
val_ds = (
    val_ds
    .cache()
    .map(rand_crop, num_parallel_calls=MAP_AUTOTUNE)
    .prefetch(AUTOTUNE)
)

# %%
# img = next(iter(test_ds))
# figsize = (7, 7)
# fig = plt.figure(figsize=figsize)
# ax = fig.add_axes([0, 0, 1, 1])
# ax.axis('off')
# ax.imshow(img)
# plt.title('Test Image')
# plt.show()

# %%
# img = next(iter(test_ds))
# figsize = (7, 7)
# fig = plt.figure(figsize=figsize)
# ax = fig.add_axes([0, 0, 1, 1])
# ax.axis('off')
# ax.imshow(img)
# plt.title('Test Image')
# plt.show()

# %% [markdown]
# ## Define Model Input and Ground Truth

# %%
def define_in_out(x):
    return x, x

# %%
# from utils.jpeg_utils import jpeg_encode_decode
# QUALITY = 70

# def define_in_out(x):
#     return jpeg_encode_decode(x, QUALITY), x

# %%
train_ds = (
    train_ds
    .map(define_in_out, num_parallel_calls=MAP_AUTOTUNE)
    .prefetch(AUTOTUNE)
)
val_ds = (
    val_ds
    .map(define_in_out, num_parallel_calls=MAP_AUTOTUNE)
    .prefetch(AUTOTUNE)
)

# %% [markdown]
# ## Model Training:

# %%
# Import Model:
# from models.AutoEncoder import getModel
# from models.AutoEncoder_v2 import getModel
# from models.AutoEncoder_v3 import getModel
# from models.AutoEncoder_v4 import getModel
# from models.AutoEncoder_v5 import getModel
# from models.AutoEncoder_v6 import getModel
# from models.AutoEncoder_v7 import getModel
# from models.AutoEncoder_v8 import getModel
# from models.AutoEncoder_v9 import getModel
# from models.AutoEncoder_v10 import getModel
# from models.AutoEncoder_v11 import getModel
# from models.AutoEncoder_v12 import getModel
# from models.AutoEncoder_v13 import getModel
# from models.AutoEncoder_v14 import getModel
# from models.AutoEncoder_v15 import getModel
# from models.AutoEncoder_v16_jarvis import getModel
# from models.AutoEncoder_v17_jarvis import getModel
# from models.AutoEncoder_v18_jarvis import getModel
from models.AutoEncoder_v19_jarvis import getModel

# %%
# Hyperparameters:
INPUT_SHAPE = [None, None, 3]
KERNEL_SIZE = [11, 11]#[7, 7]#[11, 11]#[7, 7]
DILATION_RATE = 2
BATCH_SIZE = 32#16#8
EPOCHS = 200
FILTERS = 4#2#4#8#32
# DROP_PROB = 0.05#0.075#0.05#0.075#0.25#0.1#0.05
KERNEL_REGULARIZER = tf.keras.regularizers.L2(0.0001)#None#tf.keras.regularizers.L2(0.0001)#None#tf.keras.regularizers.L2(0.0001)
KERNEL_INITIALIZER = "glorot_normal"#"orthogonal"#"glorot_normal"#"orthogonal"
DROP_PROB = None#0.05#None#0#0.15
INITIAL_LR = 0.005#0.001
LR_DECAY = 0.97#0.96#0.98#0.95#0.9#0.97#0.95#0.97#0.93
LR_DECAY_START = 10#25
ACTIVATION = 'elu'
AUGMENTATIONS = 20#10#1#10
VAL_AUGMENTATIONS = 10#1#10#5#10#100
MODEL_DIR = f'saved_models_{GPU}'
BUFFER_SIZE = 800
UPDATE_INFO_EVERY_X_EPOCHS = 25#47#94#310
delete_previous = True
SAVE_METRIC = 'val_loss'

# %%
model_kwargs = {'filters': FILTERS,
                'kernel_size': KERNEL_SIZE, 
                'activation': ACTIVATION,
                'dilation_rate': DILATION_RATE,
                'prob': DROP_PROB,
                'kernel_initializer': KERNEL_INITIALIZER,
                'kernel_regularizer': KERNEL_REGULARIZER}

# %%
# from utils.model_utils import model_loss
# USE_MSE = False
# if USE_MSE:
#     B1 = 1.0
#     B2 = 0.000075
# else:
#     # MAE
#     B1 = 1.0
#     B2 = 0.004
# loss_func = model_loss(B1, B2, mse = USE_MSE, name='loss')

from utils.model_utils import model_loss, PSNR, SSIM
# B1 = 1.0
# B2 = 0.0025#0.01#0.0025
# B3 = 0.0075 #0.005
# B4 = 0.03 #0.01
# B5 = 0#B1/50
# B6 = 0#B1/50
# weighted_fft = True
# B2 = 0.2#0.1
# loss_func = model_loss(B1, B2, B3, B4, B5, B6, mse=False,
#                        weighted_fft=weighted_fft, name='loss',
#                        input_type=input_type)
B1 = 1
B2 = 0.0025
loss_func = tf.keras.losses.MeanAbsoluteError()#model_loss(B1, B2, mse=True, name='loss')

# %%
# B1 = 0
# B2 = 0
# B3 = 0
# B4 = 0
# B5 = 0
# B6 = 0
# weighted_fft = True
# B2 = 1
# weighted_fft_func = model_loss(B1, B2, B3, B4, B5, B6, mse=False,
#                                weighted_fft=weighted_fft, name='weighted_fft_loss',
#                                input_type=input_type)

# %%
train_ds = (
    train_ds
    .prefetch(AUTOTUNE)
    .shuffle(BUFFER_SIZE)
    .batch(BATCH_SIZE)
    .repeat()
    .prefetch(AUTOTUNE)
)
val_ds = (
    val_ds
    .prefetch(AUTOTUNE)
    .shuffle(BUFFER_SIZE//4)# was //8
    .batch(BATCH_SIZE)
    .repeat()
    .prefetch(AUTOTUNE)
)

# %%
# def scheduler(epoch, lr):
#     if epoch < LR_DECAY_START:
#         return lr
#     else:
#         return lr*LR_DECAY
# def scheduler(epoch, lr):
#     if epoch % 25 != 0 or epoch < 25:
#         return lr
#     else:
#         return lr * 0.5

# def scheduler(epoch, lr):
#     if epoch < LR_DECAY_START:
#         return lr
#     elif epoch >= LR_DECAY_START: #and epoch != 100:
#         return lr*LR_DECAY

#     elif epoch == 100:
#         return INITIAL_LR

# %%
def scheduler(epoch, lr):
    if epoch <= LR_DECAY_START:
        return (epoch/LR_DECAY_START)*INITIAL_LR + INITIAL_LR/10000
    elif epoch < 2*LR_DECAY_START:
        return lr
    elif epoch >= 2*LR_DECAY_START:
        return lr*LR_DECAY

# %%
model = getModel(input_shape=INPUT_SHAPE, **model_kwargs)

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=INITIAL_LR)#, amsgrad=True)#, clipvalue=10)
if use_mixed_prec:
    optimizer = mixed_precision.LossScaleOptimizer(optimizer)
model.compile(optimizer=optimizer,  # pick an optimizer
              loss=loss_func,
              steps_per_execution=((AUGMENTATIONS) * np.ceil(NUM_TRAIN/BATCH_SIZE)) // UPDATE_INFO_EVERY_X_EPOCHS,
              metrics=['mean_absolute_error', 'mean_squared_error', SSIM, PSNR])

# %%
model.summary()
# Out:
# Model: "AutoEncoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  img (InputLayer)               [(None, None, None,  0           []
#                                  3)]
#
#  conv2d (Conv2D)                (None, None, None,   1456        ['img[0][0]']
#                                 4)
#
#  batch_normalization (BatchNorm  (None, None, None,   16         ['conv2d[0][0]']
#  alization)                     4)
#
#  conv2d_1 (Conv2D)              (None, None, None,   1940        ['batch_normalization[0][0]']
#                                 4)
#
#  conv2d_2 (Conv2D)              (None, None, None,   16          ['img[0][0]']
#                                 4)
#
#  batch_normalization_1 (BatchNo  (None, None, None,   16         ['conv2d_1[0][0]']
#  rmalization)                   4)
#
#  batch_normalization_2 (BatchNo  (None, None, None,   16         ['conv2d_2[0][0]']
#  rmalization)                   4)
#
#  add (Add)                      (None, None, None,   0           ['batch_normalization_1[0][0]',
#                                 4)                                'batch_normalization_2[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, None, None,   0           ['add[0][0]']
#                                 4)
#
#  conv2d_3 (Conv2D)              (None, None, None,   3880        ['max_pooling2d[0][0]']
#                                 8)
#
#  batch_normalization_3 (BatchNo  (None, None, None,   32         ['conv2d_3[0][0]']
#  rmalization)                   8)
#
#  conv2d_4 (Conv2D)              (None, None, None,   7752        ['batch_normalization_3[0][0]']
#                                 8)
#
#  conv2d_5 (Conv2D)              (None, None, None,   40          ['max_pooling2d[0][0]']
#                                 8)
#
#  batch_normalization_4 (BatchNo  (None, None, None,   32         ['conv2d_4[0][0]']
#  rmalization)                   8)
#
#  batch_normalization_5 (BatchNo  (None, None, None,   32         ['conv2d_5[0][0]']
#  rmalization)                   8)
#
#  add_1 (Add)                    (None, None, None,   0           ['batch_normalization_4[0][0]',
#                                 8)                                'batch_normalization_5[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, None, None,   0          ['add_1[0][0]']
#                                 8)
#
#  conv2d_6 (Conv2D)              (None, None, None,   15504       ['max_pooling2d_1[0][0]']
#                                 16)
#
#  batch_normalization_6 (BatchNo  (None, None, None,   64         ['conv2d_6[0][0]']
#  rmalization)                   16)
#
#  conv2d_7 (Conv2D)              (None, None, None,   30992       ['batch_normalization_6[0][0]']
#                                 16)
#
#  conv2d_8 (Conv2D)              (None, None, None,   144         ['max_pooling2d_1[0][0]']
#                                 16)
#
#  batch_normalization_7 (BatchNo  (None, None, None,   64         ['conv2d_7[0][0]']
#  rmalization)                   16)
#
#  batch_normalization_8 (BatchNo  (None, None, None,   64         ['conv2d_8[0][0]']
#  rmalization)                   16)
#
#  add_2 (Add)                    (None, None, None,   0           ['batch_normalization_7[0][0]',
#                                 16)                               'batch_normalization_8[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, None, None,   0          ['add_2[0][0]']
#                                 16)
#
#  conv2d_9 (Conv2D)              (None, None, None,   61984       ['max_pooling2d_2[0][0]']
#                                 32)
#
#  batch_normalization_9 (BatchNo  (None, None, None,   128        ['conv2d_9[0][0]']
#  rmalization)                   32)
#
#  conv2d_10 (Conv2D)             (None, None, None,   123936      ['batch_normalization_9[0][0]']
#                                 32)
#
#  conv2d_11 (Conv2D)             (None, None, None,   544         ['max_pooling2d_2[0][0]']
#                                 32)
#
#  batch_normalization_10 (BatchN  (None, None, None,   128        ['conv2d_10[0][0]']
#  ormalization)                  32)
#
#  batch_normalization_11 (BatchN  (None, None, None,   128        ['conv2d_11[0][0]']
#  ormalization)                  32)
#
#  add_3 (Add)                    (None, None, None,   0           ['batch_normalization_10[0][0]',
#                                 32)                               'batch_normalization_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, None, None,   123936      ['add_3[0][0]']
#                                 32)
#
#  batch_normalization_12 (BatchN  (None, None, None,   128        ['conv2d_12[0][0]']
#  ormalization)                  32)
#
#  conv2d_13 (Conv2D)             (None, None, None,   123936      ['batch_normalization_12[0][0]']
#                                 32)
#
#  conv2d_14 (Conv2D)             (None, None, None,   1056        ['add_3[0][0]']
#                                 32)
#
#  batch_normalization_13 (BatchN  (None, None, None,   128        ['conv2d_13[0][0]']
#  ormalization)                  32)
#
#  batch_normalization_14 (BatchN  (None, None, None,   128        ['conv2d_14[0][0]']
#  ormalization)                  32)
#
#  conv2d_15 (Conv2D)             (None, None, None,   544         ['max_pooling2d_2[0][0]']
#                                 32)
#
#  add_4 (Add)                    (None, None, None,   0           ['batch_normalization_13[0][0]',
#                                 32)                               'batch_normalization_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, None, None,   128        ['conv2d_15[0][0]']
#  ormalization)                  32)
#
#  add_5 (Add)                    (None, None, None,   0           ['add_4[0][0]',
#                                 32)                               'batch_normalization_15[0][0]']
#
#  tf.math.reduce_min (TFOpLambda  (None, 1, 1, 1)     0           ['add_5[0][0]']
#  )
#
#  tf.math.reduce_max (TFOpLambda  (None, 1, 1, 1)     0           ['add_5[0][0]']
#  )
#
#  tf.math.subtract (TFOpLambda)  (None, None, None,   0           ['add_5[0][0]',
#                                 32)                               'tf.math.reduce_min[0][0]']
#
#  tf.math.subtract_1 (TFOpLambda  (None, 1, 1, 1)     0           ['tf.math.reduce_max[0][0]',
#  )                                                                'tf.math.reduce_min[0][0]']
#
#  tf.math.divide_no_nan (TFOpLam  (None, None, None,   0          ['tf.math.subtract[0][0]',
#  bda)                           32)                               'tf.math.subtract_1[0][0]']
#
#  conv2d_17 (Conv2D)             (None, None, None,   123936      ['tf.math.divide_no_nan[0][0]']
#                                 32)
#
#  batch_normalization_17 (BatchN  (None, None, None,   128        ['conv2d_17[0][0]']
#  ormalization)                  32)
#
#  conv2d_18 (Conv2D)             (None, None, None,   123936      ['batch_normalization_17[0][0]']
#                                 32)
#
#  conv2d_19 (Conv2D)             (None, None, None,   1056        ['tf.math.divide_no_nan[0][0]']
#                                 32)
#
#  batch_normalization_18 (BatchN  (None, None, None,   128        ['conv2d_18[0][0]']
#  ormalization)                  32)
#
#  batch_normalization_19 (BatchN  (None, None, None,   128        ['conv2d_19[0][0]']
#  ormalization)                  32)
#
#  add_6 (Add)                    (None, None, None,   0           ['batch_normalization_18[0][0]',
#                                 32)                               'batch_normalization_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, None, None,   123936      ['add_6[0][0]']
#                                 32)
#
#  batch_normalization_20 (BatchN  (None, None, None,   128        ['conv2d_20[0][0]']
#  ormalization)                  32)
#
#  conv2d_21 (Conv2D)             (None, None, None,   123936      ['batch_normalization_20[0][0]']
#                                 32)
#
#  conv2d_22 (Conv2D)             (None, None, None,   1056        ['add_6[0][0]']
#                                 32)
#
#  batch_normalization_21 (BatchN  (None, None, None,   128        ['conv2d_21[0][0]']
#  ormalization)                  32)
#
#  batch_normalization_22 (BatchN  (None, None, None,   128        ['conv2d_22[0][0]']
#  ormalization)                  32)
#
#  conv2d_16 (Conv2D)             (None, None, None,   1056        ['tf.math.divide_no_nan[0][0]']
#                                 32)
#
#  add_7 (Add)                    (None, None, None,   0           ['batch_normalization_21[0][0]',
#                                 32)                               'batch_normalization_22[0][0]']
#
#  batch_normalization_16 (BatchN  (None, None, None,   128        ['conv2d_16[0][0]']
#  ormalization)                  32)
#
#  add_8 (Add)                    (None, None, None,   0           ['add_7[0][0]',
#                                 32)                               'batch_normalization_16[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, None, None,   65568      ['add_8[0][0]']
#  ose)                           32)
#
#  batch_normalization_23 (BatchN  (None, None, None,   128        ['conv2d_transpose[0][0]']
#  ormalization)                  32)
#
#  conv2d_23 (Conv2D)             (None, None, None,   61968       ['batch_normalization_23[0][0]']
#                                 16)
#
#  batch_normalization_24 (BatchN  (None, None, None,   64         ['conv2d_23[0][0]']
#  ormalization)                  16)
#
#  conv2d_24 (Conv2D)             (None, None, None,   30992       ['batch_normalization_24[0][0]']
#                                 16)
#
#  conv2d_25 (Conv2D)             (None, None, None,   528         ['batch_normalization_23[0][0]']
#                                 16)
#
#  batch_normalization_25 (BatchN  (None, None, None,   64         ['conv2d_24[0][0]']
#  ormalization)                  16)
#
#  batch_normalization_26 (BatchN  (None, None, None,   64         ['conv2d_25[0][0]']
#  ormalization)                  16)
#
#  add_9 (Add)                    (None, None, None,   0           ['batch_normalization_25[0][0]',
#                                 16)                               'batch_normalization_26[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, None, None,   16400      ['add_9[0][0]']
#  spose)                         16)
#
#  batch_normalization_27 (BatchN  (None, None, None,   64         ['conv2d_transpose_1[0][0]']
#  ormalization)                  16)
#
#  conv2d_26 (Conv2D)             (None, None, None,   15496       ['batch_normalization_27[0][0]']
#                                 8)
#
#  batch_normalization_28 (BatchN  (None, None, None,   32         ['conv2d_26[0][0]']
#  ormalization)                  8)
#
#  conv2d_27 (Conv2D)             (None, None, None,   7752        ['batch_normalization_28[0][0]']
#                                 8)
#
#  conv2d_28 (Conv2D)             (None, None, None,   136         ['batch_normalization_27[0][0]']
#                                 8)
#
#  batch_normalization_29 (BatchN  (None, None, None,   32         ['conv2d_27[0][0]']
#  ormalization)                  8)
#
#  batch_normalization_30 (BatchN  (None, None, None,   32         ['conv2d_28[0][0]']
#  ormalization)                  8)
#
#  add_10 (Add)                   (None, None, None,   0           ['batch_normalization_29[0][0]',
#                                 8)                                'batch_normalization_30[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, None, None,   4104       ['add_10[0][0]']
#  spose)                         8)
#
#  batch_normalization_31 (BatchN  (None, None, None,   32         ['conv2d_transpose_2[0][0]']
#  ormalization)                  8)
#
#  conv2d_29 (Conv2D)             (None, None, None,   3876        ['batch_normalization_31[0][0]']
#                                 4)
#
#  batch_normalization_32 (BatchN  (None, None, None,   16         ['conv2d_29[0][0]']
#  ormalization)                  4)
#
#  conv2d_30 (Conv2D)             (None, None, None,   1940        ['batch_normalization_32[0][0]']
#                                 4)
#
#  conv2d_31 (Conv2D)             (None, None, None,   36          ['batch_normalization_31[0][0]']
#                                 4)
#
#  batch_normalization_33 (BatchN  (None, None, None,   16         ['conv2d_30[0][0]']
#  ormalization)                  4)
#
#  batch_normalization_34 (BatchN  (None, None, None,   16         ['conv2d_31[0][0]']
#  ormalization)                  4)
#
#  add_11 (Add)                   (None, None, None,   0           ['batch_normalization_33[0][0]',
#                                 4)                                'batch_normalization_34[0][0]']
#
#  conv2d_32 (Conv2D)             (None, None, None,   15          ['add_11[0][0]']
#                                 3)
#
#  tf.math.reduce_min_1 (TFOpLamb  (None, 1, 1, 1)     0           ['conv2d_32[0][0]']
#  da)
#
#  tf.math.reduce_max_1 (TFOpLamb  (None, 1, 1, 1)     0           ['conv2d_32[0][0]']
#  da)
#
#  tf.math.subtract_2 (TFOpLambda  (None, None, None,   0          ['conv2d_32[0][0]',
#  )                              3)                                'tf.math.reduce_min_1[0][0]']
#
#  tf.math.subtract_3 (TFOpLambda  (None, 1, 1, 1)     0           ['tf.math.reduce_max_1[0][0]',
#  )                                                                'tf.math.reduce_min_1[0][0]']
#
#  tf.math.divide_no_nan_1 (TFOpL  (None, None, None,   0          ['tf.math.subtract_2[0][0]',
#  ambda)                         3)                                'tf.math.subtract_3[0][0]']
#
# ==================================================================================================
# Total params: 1,208,071
# Trainable params: 1,206,727
# Non-trainable params: 1,344
# __________________________________________________________________________________________________

# %%
if not os.path.exists(MODEL_DIR):
    os.mkdir(MODEL_DIR)
elif delete_previous:
    shutil.rmtree(MODEL_DIR)
    os.mkdir(MODEL_DIR)

lr_schedule = tf.keras.callbacks.LearningRateScheduler(scheduler)
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=os.path.join(MODEL_DIR, 
                                                                            'saved_model-epoch_{epoch:02d}-' + 
                                                                            SAVE_METRIC + '_{' + 
                                                                            SAVE_METRIC + ':.5f}.h5'),
                                                      monitor=SAVE_METRIC,
                                                      verbose=0,
                                                      save_best_only=True,
                                                      save_weights_only=False,
                                                      mode='min',
                                                      save_freq='epoch')

my_callbacks = [model_checkpoint, lr_schedule]

history = model.fit(train_ds,
                    steps_per_epoch=AUGMENTATIONS*np.ceil(NUM_TRAIN/BATCH_SIZE),
                    epochs=EPOCHS,
                    callbacks=my_callbacks,
                    validation_data=val_ds,
                    validation_steps=VAL_AUGMENTATIONS*np.ceil(NUM_VAL/BATCH_SIZE),
                    max_queue_size=10*AUGMENTATIONS*np.ceil(NUM_TRAIN/BATCH_SIZE))
# Out:
# Epoch 1/200
# 500/500 [==============================] - 299s 597ms/step - loss: 0.3044 - mean_absolute_error: 0.2397 - mean_squared_error: 0.0804 - SSIM: 0.0725 - PSNR: 11.4488 - val_loss: 0.2807 - val_mean_absolute_error: 0.2160 - val_mean_squared_error: 0.0657 - val_SSIM: 0.0875 - val_PSNR: 12.2582 - lr: 5.0000e-07
# Epoch 2/200
# 500/500 [==============================] - 242s 485ms/step - loss: 0.2153 - mean_absolute_error: 0.1526 - mean_squared_error: 0.0399 - SSIM: 0.2782 - PSNR: 15.0031 - val_loss: 0.2084 - val_mean_absolute_error: 0.1482 - val_mean_squared_error: 0.0359 - val_SSIM: 0.2689 - val_PSNR: 14.8289 - lr: 5.0050e-04
# Epoch 3/200
# 500/500 [==============================] - 243s 485ms/step - loss: 0.1530 - mean_absolute_error: 0.0984 - mean_squared_error: 0.0178 - SSIM: 0.3744 - PSNR: 18.4586 - val_loss: 0.1388 - val_mean_absolute_error: 0.0899 - val_mean_squared_error: 0.0149 - val_SSIM: 0.4324 - val_PSNR: 19.1259 - lr: 0.0010
# Epoch 4/200
# 500/500 [==============================] - 247s 494ms/step - loss: 0.1278 - mean_absolute_error: 0.0866 - mean_squared_error: 0.0140 - SSIM: 0.4261 - PSNR: 19.5489 - val_loss: 0.1173 - val_mean_absolute_error: 0.0833 - val_mean_squared_error: 0.0124 - val_SSIM: 0.4538 - val_PSNR: 19.7456 - lr: 0.0015
200
# 500/500 [==============================] - 242s 484ms/step - loss: 0.0543 - mean_absolute_error: 0.0528 - mean_squared_error: 0.0069 - SSIM: 0.6384 - PSNR: 24.0519 - val_loss: 0.1268 - val_mean_absolute_error: 0.1253 - val_mean_squared_error: 0.0223 - val_SSIM: 0.4905 - val_PSNR: 16.9962 - lr: 2.1051e-04
# Epoch 125/200
# 500/500 [==============================] - 242s 484ms/step - loss: 0.0539 - mean_absolute_error: 0.0523 - mean_squared_error: 0.0068 - SSIM: 0.6437 - PSNR: 24.1240 - val_loss: 0.1063 - val_mean_absolute_error: 0.1048 - val_mean_squared_error: 0.0162 - val_SSIM: 0.5907 - val_PSNR: 18.5219 - lr: 2.0420e-04
# Epoch 126/200
# 500/500 [==============================] - 242s 484ms/step - loss: 0.0534 - mean_absolute_error: 0.0519 - mean_squared_error: 0.0067 - SSIM: 0.6460 - PSNR: 24.2159 - val_loss: 0.0881 - val_mean_absolute_error: 0.0866 - val_mean_squared_error: 0.0143 - val_SSIM: 0.3305 - val_PSNR: 19.2110 - lr: 1.9807e-04
# Epoch 127/200
# 500/500 [==============================] - 241s 482ms/step - loss: 0.0536 - mean_absolute_error: 0.0521 - mean_squared_error: 0.0067 - SSIM: 0.6433 - PSNR: 24.1608 - val_loss: 0.0609 - val_mean_absolute_error: 0.0594 - val_mean_squared_error: 0.0074 - val_SSIM: 0.6462 - val_PSNR: 22.8116 - lr: 1.9213e-04
# Epoch 128/200
# 500/500 [==============================] - 241s 483ms/step - loss: 0.0538 - mean_absolute_error: 0.0523 - mean_squared_error: 0.0067 - SSIM: 0.6422 - PSNR: 24.1382 - val_loss: 0.0672 - val_mean_absolute_error: 0.0657 - val_mean_squared_error: 0.0085 - val_SSIM: 0.5108 - val_PSNR: 21.8288 - lr: 1.8636e-04
# Epoch 129/200
# 500/500 [==============================] - 242s 484ms/step - loss: 0.0533 - mean_absolute_error: 0.0518 - mean_squared_error: 0.0067 - SSIM: 0.6433 - PSNR: 24.2110 - val_loss: 0.0761 - val_mean_absolute_error: 0.0747 - val_mean_squared_error: 0.0111 - val_SSIM: 0.5976 - val_PSNR: 20.5301 - lr: 1.8077e-04
# Epoch 130/200
# 500/500 [==============================] - 242s 484ms/step - loss: 0.0531 - mean_absolute_error: 0.0516 - mean_squared_error: 0.0067 - SSIM: 0.6457 - PSNR: 24.2563 - val_loss: 0.0868 - val_mean_absolute_error: 0.0853 - val_mean_squared_error: 0.0128 - val_SSIM: 0.5083 - val_PSNR: 19.6209 - lr: 1.7535e-04
# Epoch 131/200
# 500/500 [==============================] - 242s 483ms/step - loss: 0.0537 - mean_absolute_error: 0.0522 - mean_squared_error: 0.0067 - SSIM: 0.6441 - PSNR: 24.1677 - val_loss: 0.0590 - val_mean_absolute_error: 0.0575 - val_mean_squared_error: 0.0072 - val_SSIM: 0.6061 - val_PSNR: 22.9575 - lr: 1.7009e-04
# Epoch 132/200
# 500/500 [==============================] - 257s 513ms/step - loss: 0.0534 - mean_absolute_error: 0.0519 - mean_squared_error: 0.0067 - SSIM: 0.6444 - PSNR: 24.1875 - val_loss: 0.0495 - val_mean_absolute_error: 0.0481 - val_mean_squared_error: 0.0064 - val_SSIM: 0.6592 - val_PSNR: 24.2940 - lr: 1.6499e-04
# Epoch 133/200
# 500/500 [==============================] - 229s 457ms/step - loss: 0.0537 - mean_absolute_error: 0.0522 - mean_squared_error: 0.0067 - SSIM: 0.6424 - PSNR: 24.1536 - val_loss: 0.0579 - val_mean_absolute_error: 0.0564 - val_mean_squared_error: 0.0074 - val_SSIM: 0.5956 - val_PSNR: 22.8926 - lr: 1.6004e-04
# Epoch 134/200
# 500/500 [==============================] - 242s 483ms/step - loss: 0.0529 - mean_absolute_error: 0.0514 - mean_squared_error: 0.0066 - SSIM: 0.6490 - PSNR: 24.2847 - val_loss: 0.0673 - val_mean_absolute_error: 0.0658 - val_mean_squared_error: 0.0090 - val_SSIM: 0.6461 - val_PSNR: 21.6561 - lr: 1.5524e-04
# Epoch 135/200
# 500/500 [==============================] - 241s 482ms/step - loss: 0.0535 - mean_absolute_error: 0.0520 - mean_squared_error: 0.0067 - SSIM: 0.6459 - PSNR: 24.1824 - val_loss: 0.0863 - val_mean_absolute_error: 0.0849 - val_mean_squared_error: 0.0126 - val_SSIM: 0.5281 - val_PSNR: 19.7811 - lr: 1.5058e-04
# Epoch 136/200
# 500/500 [==============================] - 242s 483ms/step - loss: 0.0536 - mean_absolute_error: 0.0522 - mean_squared_error: 0.0067 - SSIM: 0.6445 - PSNR: 24.1367 - val_loss: 0.0544 - val_mean_absolute_error: 0.0529 - val_mean_squared_error: 0.0067 - val_SSIM: 0.6632 - val_PSNR: 23.6453 - lr: 1.4606e-04
# Epoch 137/200
# 500/500 [==============================] - 242s 483ms/step - loss: 0.0533 - mean_absolute_error: 0.0518 - mean_squared_error: 0.0066 - SSIM: 0.6458 - PSNR: 24.1922 - val_loss: 0.0674 - val_mean_absolute_error: 0.0659 - val_mean_squared_error: 0.0090 - val_SSIM: 0.6354 - val_PSNR: 21.7214 - lr: 1.4168e-04
# Epoch 138/200
# 500/500 [==============================] - 242s 483ms/step - loss: 0.0532 - mean_absolute_error: 0.0518 - mean_squared_error: 0.0067 - SSIM: 0.6450 - PSNR: 24.2133 - val_loss: 0.0765 - val_mean_absolute_error: 0.0750 - val_mean_squared_error: 0.0104 - val_SSIM: 0.4909 - val_PSNR: 20.4787 - lr: 1.3743e-04
# Epoch 139/200
# 500/500 [==============================] - 241s 482ms/step - loss: 0.0534 - mean_absolute_error: 0.0520 - mean_squared_error: 0.0067 - SSIM: 0.6448 - PSNR: 24.2169 - val_loss: 0.0586 - val_mean_absolute_error: 0.0571 - val_mean_squared_error: 0.0072 - val_SSIM: 0.6675 - val_PSNR: 23.0921 - lr: 1.3331e-04
# Epoch 140/200
# 500/500 [==============================] - 241s 482ms/step - loss: 0.0537 - mean_absolute_error: 0.0522 - mean_squared_error: 0.0067 - SSIM: 0.6437 - PSNR: 24.1433 - val_loss: 0.1065 - val_mean_absolute_error: 0.1051 - val_mean_squared_error: 0.0186 - val_SSIM: 0.4207 - val_PSNR: 17.8238 - lr: 1.2931e-04
# Epoch 141/200
# 500/500 [==============================] - 241s 483ms/step - loss: 0.0532 - mean_absolute_error: 0.0518 - mean_squared_error: 0.0067 - SSIM: 0.6469 - PSNR: 24.2377 - val_loss: 0.0557 - val_mean_absolute_error: 0.0543 - val_mean_squared_error: 0.0071 - val_SSIM: 0.6539 - val_PSNR: 23.3729 - lr: 1.2543e-04
# Epoch 142/200
# 500/500 [==============================] - 241s 482ms/step - loss: 0.0536 - mean_absolute_error: 0.0521 - mean_squared_error: 0.0067 - SSIM: 0.6454 - PSNR: 24.1765 - val_loss: 0.0638 - val_mean_absolute_error: 0.0623 - val_mean_squared_error: 0.0082 - val_SSIM: 0.6606 - val_PSNR: 22.2856 - lr: 1.2166e-04
# Epoch 143/200
# 500/500 [==============================] - 241s 482ms/step - loss: 0.0534 - mean_absolute_error: 0.0519 - mean_squared_error: 0.0067 - SSIM: 0.6441 - PSNR: 24.1998 - val_loss: 0.0505 - val_mean_absolute_error: 0.0491 - val_mean_squared_error: 0.0063 - val_SSIM: 0.6326 - val_PSNR: 24.1882 - lr: 1.1801e-04
# Epoch 144/200
# 500/500 [==============================] - 241s 482ms/step - loss: 0.
# %%
from utils.history_utils import show_history
offset = 0
show_history(history, offset)

# %%
from utils.history_utils import show_history
offset = 0
show_history(history, offset)

# %%
from utils.history_utils import show_history
offset = 0
show_history(history, offset)

# %%
from utils.history_utils import show_history
offset = 0
show_history(history, offset)

# %%
from utils.history_utils import show_history
offset = 0
show_history(history, offset)

# %%
from utils.history_utils import show_history
offset = 0
show_history(history, offset)

# %%
from utils.history_utils import show_history
offset = 0
show_history(history, offset)

# %%
from utils.history_utils import show_history
offset = 0
show_history(history, offset)

# %%
from utils.history_utils import show_history
offset = 0
show_history(history, offset)

# %%
from utils.history_utils import show_history
offset = 0
show_history(history, offset)

# %%
from utils.history_utils import show_history
offset = 0
show_history(history, offset)

# %% [markdown]
# ### Save Model and History into Folder

# %%
description = '''
Description:
Fixed data augmentation error.
Simple Autoencoder Compression to 32 x 32 x 32 compressed state: ratio of 1:6
Spatial Dropout p=0 and Prob Aug = 1/2 - removed stateless augmentations/rng wrap (see leg for stateless)
Without Pixel Shuffle (replaced by Conv Transpose)
Added residual blocks, more encoded convs after transmission, and norm back to math operations
Last layer also is a residual block now. Uses glorot normal initialization with L2 Reg (0.0001)

# Hyperparameters:
INPUT_SHAPE = [None, None, 3]
KERNEL_SIZE = [11, 11]#[7, 7]#[11, 11]#[7, 7]
DILATION_RATE = 2
BATCH_SIZE = 32#16#8
EPOCHS = 200
FILTERS = 4#2#4#8#32
# DROP_PROB = 0.05#0.075#0.05#0.075#0.25#0.1#0.05
KERNEL_REGULARIZER = tf.keras.regularizers.L2(0.0001)#None#tf.keras.regularizers.L2(0.0001)#None#tf.keras.regularizers.L2(0.0001)
KERNEL_INITIALIZER = "glorot_normal"#"orthogonal"#"glorot_normal"#"orthogonal"
DROP_PROB = None#0.05#None#0#0.15
INITIAL_LR = 0.005#0.001
LR_DECAY = 0.97#0.96#0.98#0.95#0.9#0.97#0.95#0.97#0.93
LR_DECAY_START = 10#25
ACTIVATION = 'elu'
AUGMENTATIONS = 20#10#1#10
VAL_AUGMENTATIONS = 10#1#10#5#10#100

Changed lr_schedule to :

def scheduler(epoch, lr):
    if epoch <= LR_DECAY_START:
        return (epoch/LR_DECAY_START)*INITIAL_LR + INITIAL_LR/10000
    elif epoch < 2*LR_DECAY_START:
        return lr
    elif epoch >= 2*LR_DECAY_START:
        return lr*LR_DECAY

with LR_DECAY_START=10, LR_DECAY=0.96, and INITIAL_LR=0.005'''
save_last_x_best_models = 2

if not os.path.exists('./trained_models'):
    os.mkdir('./trained_models')
output_dir = f'trained_models/saved_{model.name.lower()}_gpu{GPU}'

if not os.path.exists(output_dir):
    print(f'Creating New Directory at {output_dir}...')
    os.mkdir(output_dir)
else:
    print('Directory Already Exists...')
    output_dir += '_v1'
    while os.path.exists(output_dir):
        v_num = int(output_dir[-5:].partition('_v')[-1])
        output_dir = output_dir.partition(f'_v{v_num}')[0]
        v_num += 1
        output_dir += f'_v{v_num}'
    print(f'Creating New Directory at {output_dir}...')
    os.mkdir(output_dir)
final_val_loss = history.history['val_loss'][-1]
model.save(os.path.join(output_dir, f'saved_model-epoch_{EPOCHS}-val_loss_{final_val_loss:0.4f}.h5'))
best_model_dir = os.path.join(output_dir, 'best_models')
if not os.path.exists(best_model_dir):
    os.mkdir(best_model_dir)
print('Saving Best Model(s)...')
for i in range(save_last_x_best_models):
    file_list = [file for file in os.listdir(MODEL_DIR) if os.path.isfile(os.path.join(MODEL_DIR, file))]
    filename = sorted(file_list, key=lambda x: int(x.partition('h_')[2].partition('-')[0]))[-1]
    old_path = os.path.join(MODEL_DIR, filename)
    new_path = os.path.join(best_model_dir, filename)
    os.rename(old_path, new_path)
print('Saving History...')
save_history(history, output_dir)
print('Saving Description...')
with open(os.path.join(output_dir, "description.txt"), "a") as f:
    f.write(description)
print('Done!!!')
# Out:
# Directory Already Exists...
# Creating New Directory at trained_models/saved_autoencoder_gpu0_v19...
# Saving Best Model(s)...
# Saving History...
# Saving Description...
# Done!!!

# %% [markdown]
# ### Load Model

# %%
input_dir = 'saved_autoencoder_gpu0'

# %%
#model = tf.keras.models.load_model('./saved_models/saved_model-epoch_08-val_loss_0.01138.h5', compile=False)

# %%
input_dir = os.path.join('./trained_models', input_dir)
best_model_dir = os.path.join(input_dir, 'best_models')
file_list = [file for file in os.listdir(best_model_dir) if os.path.isfile(os.path.join(best_model_dir, file))]
filename = sorted(file_list, key = lambda x : int(x.partition('h_')[2].partition('-')[0]))[-1]
path = os.path.join(best_model_dir, filename)
print('Loading Model...')
print(f'Model Path: {path}')
model = tf.keras.models.load_model(path, compile=False)
print('Done!!!')
# Out:
# Loading Model...
# Model Path: ./trained_models/saved_autoencoder_gpu0/best_models/saved_model-epoch_115-val_loss_0.07574.h5
# Done!!!

# %%
model2.name
# Out:
# 'AutoEncoder'

# %%
model.summary()
# Out:
# Model: "AutoEncoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  img (InputLayer)               [(None, None, None,  0           []
#                                  3)]
#
#  conv2d (Conv2D)                (None, None, None,   1456        ['img[0][0]']
#                                 4)
#
#  batch_normalization (BatchNorm  (None, None, None,   16         ['conv2d[0][0]']
#  alization)                     4)
#
#  conv2d_1 (Conv2D)              (None, None, None,   1940        ['batch_normalization[0][0]']
#                                 4)
#
#  batch_normalization_1 (BatchNo  (None, None, None,   16         ['conv2d_1[0][0]']
#  rmalization)                   4)
#
#  conv2d_2 (Conv2D)              (None, None, None,   1940        ['batch_normalization_1[0][0]']
#                                 4)
#
#  conv2d_3 (Conv2D)              (None, None, None,   16          ['img[0][0]']
#                                 4)
#
#  batch_normalization_2 (BatchNo  (None, None, None,   16         ['conv2d_2[0][0]']
#  rmalization)                   4)
#
#  batch_normalization_3 (BatchNo  (None, None, None,   16         ['conv2d_3[0][0]']
#  rmalization)                   4)
#
#  add (Add)                      (None, None, None,   0           ['batch_normalization_2[0][0]',
#                                 4)                                'batch_normalization_3[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, None, None,   0           ['add[0][0]']
#                                 4)
#
#  conv2d_4 (Conv2D)              (None, None, None,   3880        ['max_pooling2d[0][0]']
#                                 8)
#
#  batch_normalization_4 (BatchNo  (None, None, None,   32         ['conv2d_4[0][0]']
#  rmalization)                   8)
#
#  conv2d_5 (Conv2D)              (None, None, None,   7752        ['batch_normalization_4[0][0]']
#                                 8)
#
#  batch_normalization_5 (BatchNo  (None, None, None,   32         ['conv2d_5[0][0]']
#  rmalization)                   8)
#
#  conv2d_6 (Conv2D)              (None, None, None,   7752        ['batch_normalization_5[0][0]']
#                                 8)
#
#  conv2d_7 (Conv2D)              (None, None, None,   40          ['max_pooling2d[0][0]']
#                                 8)
#
#  batch_normalization_6 (BatchNo  (None, None, None,   32         ['conv2d_6[0][0]']
#  rmalization)                   8)
#
#  batch_normalization_7 (BatchNo  (None, None, None,   32         ['conv2d_7[0][0]']
#  rmalization)                   8)
#
#  add_1 (Add)                    (None, None, None,   0           ['batch_normalization_6[0][0]',
#                                 8)                                'batch_normalization_7[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, None, None,   0          ['add_1[0][0]']
#                                 8)
#
#  conv2d_8 (Conv2D)              (None, None, None,   15504       ['max_pooling2d_1[0][0]']
#                                 16)
#
#  batch_normalization_8 (BatchNo  (None, None, None,   64         ['conv2d_8[0][0]']
#  rmalization)                   16)
#
#  conv2d_9 (Conv2D)              (None, None, None,   30992       ['batch_normalization_8[0][0]']
#                                 16)
#
#  batch_normalization_9 (BatchNo  (None, None, None,   64         ['conv2d_9[0][0]']
#  rmalization)                   16)
#
#  conv2d_10 (Conv2D)             (None, None, None,   30992       ['batch_normalization_9[0][0]']
#                                 16)
#
#  conv2d_11 (Conv2D)             (None, None, None,   144         ['max_pooling2d_1[0][0]']
#                                 16)
#
#  batch_normalization_10 (BatchN  (None, None, None,   64         ['conv2d_10[0][0]']
#  ormalization)                  16)
#
#  batch_normalization_11 (BatchN  (None, None, None,   64         ['conv2d_11[0][0]']
#  ormalization)                  16)
#
#  add_2 (Add)                    (None, None, None,   0           ['batch_normalization_10[0][0]',
#                                 16)                               'batch_normalization_11[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, None, None,   0          ['add_2[0][0]']
#                                 16)
#
#  conv2d_12 (Conv2D)             (None, None, None,   61984       ['max_pooling2d_2[0][0]']
#                                 32)
#
#  batch_normalization_12 (BatchN  (None, None, None,   128        ['conv2d_12[0][0]']
#  ormalization)                  32)
#
#  conv2d_13 (Conv2D)             (None, None, None,   123936      ['batch_normalization_12[0][0]']
#                                 32)
#
#  batch_normalization_13 (BatchN  (None, None, None,   128        ['conv2d_13[0][0]']
#  ormalization)                  32)
#
#  conv2d_14 (Conv2D)             (None, None, None,   123936      ['batch_normalization_13[0][0]']
#                                 32)
#
#  conv2d_15 (Conv2D)             (None, None, None,   544         ['max_pooling2d_2[0][0]']
#                                 32)
#
#  batch_normalization_14 (BatchN  (None, None, None,   128        ['conv2d_14[0][0]']
#  ormalization)                  32)
#
#  batch_normalization_15 (BatchN  (None, None, None,   128        ['conv2d_15[0][0]']
#  ormalization)                  32)
#
#  add_3 (Add)                    (None, None, None,   0           ['batch_normalization_14[0][0]',
#                                 32)                               'batch_normalization_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, None, None,   123936      ['add_3[0][0]']
#                                 32)
#
#  batch_normalization_16 (BatchN  (None, None, None,   128        ['conv2d_16[0][0]']
#  ormalization)                  32)
#
#  conv2d_17 (Conv2D)             (None, None, None,   123936      ['batch_normalization_16[0][0]']
#                                 32)
#
#  batch_normalization_17 (BatchN  (None, None, None,   128        ['conv2d_17[0][0]']
#  ormalization)                  32)
#
#  conv2d_18 (Conv2D)             (None, None, None,   123936      ['batch_normalization_17[0][0]']
#                                 32)
#
#  conv2d_19 (Conv2D)             (None, None, None,   1056        ['add_3[0][0]']
#                                 32)
#
#  batch_normalization_18 (BatchN  (None, None, None,   128        ['conv2d_18[0][0]']
#  ormalization)                  32)
#
#  batch_normalization_19 (BatchN  (None, None, None,   128        ['conv2d_19[0][0]']
#  ormalization)                  32)
#
#  conv2d_20 (Conv2D)             (None, None, None,   544         ['max_pooling2d_2[0][0]']
#                                 32)
#
#  add_4 (Add)                    (None, None, None,   0           ['batch_normalization_18[0][0]',
#                                 32)                               'batch_normalization_19[0][0]']
#
#  batch_normalization_20 (BatchN  (None, None, None,   128        ['conv2d_20[0][0]']
#  ormalization)                  32)
#
#  add_5 (Add)                    (None, None, None,   0           ['add_4[0][0]',
#                                 32)                               'batch_normalization_20[0][0]']
#
#  tf.math.reduce_min (TFOpLambda  (None, 1, 1, 1)     0           ['add_5[0][0]']
#  )
#
#  tf.math.reduce_max (TFOpLambda  (None, 1, 1, 1)     0           ['add_5[0][0]']
#  )
#
#  tf.math.subtract (TFOpLambda)  (None, None, None,   0           ['add_5[0][0]',
#                                 32)                               'tf.math.reduce_min[0][0]']
#
#  tf.math.subtract_1 (TFOpLambda  (None, 1, 1, 1)     0           ['tf.math.reduce_max[0][0]',
#  )                                                                'tf.math.reduce_min[0][0]']
#
#  tf.math.divide_no_nan (TFOpLam  (None, None, None,   0          ['tf.math.subtract[0][0]',
#  bda)                           32)                               'tf.math.subtract_1[0][0]']
#
#  conv2d_22 (Conv2D)             (None, None, None,   123936      ['tf.math.divide_no_nan[0][0]']
#                                 32)
#
#  batch_normalization_22 (BatchN  (None, None, None,   128        ['conv2d_22[0][0]']
#  ormalization)                  32)
#
#  conv2d_23 (Conv2D)             (None, None, None,   123936      ['batch_normalization_22[0][0]']
#                                 32)
#
#  batch_normalization_23 (BatchN  (None, None, None,   128        ['conv2d_23[0][0]']
#  ormalization)                  32)
#
#  conv2d_24 (Conv2D)             (None, None, None,   123936      ['batch_normalization_23[0][0]']
#                                 32)
#
#  conv2d_25 (Conv2D)             (None, None, None,   1056        ['tf.math.divide_no_nan[0][0]']
#                                 32)
#
#  batch_normalization_24 (BatchN  (None, None, None,   128        ['conv2d_24[0][0]']
#  ormalization)                  32)
#
#  batch_normalization_25 (BatchN  (None, None, None,   128        ['conv2d_25[0][0]']
#  ormalization)                  32)
#
#  add_6 (Add)                    (None, None, None,   0           ['batch_normalization_24[0][0]',
#                                 32)                               'batch_normalization_25[0][0]']
#
#  conv2d_26 (Conv2D)             (None, None, None,   123936      ['add_6[0][0]']
#                                 32)
#
#  batch_normalization_26 (BatchN  (None, None, None,   128        ['conv2d_26[0][0]']
#  ormalization)                  32)
#
#  conv2d_27 (Conv2D)             (None, None, None,   123936      ['batch_normalization_26[0][0]']
#                                 32)
#
#  batch_normalization_27 (BatchN  (None, None, None,   128        ['conv2d_27[0][0]']
#  ormalization)                  32)
#
#  conv2d_28 (Conv2D)             (None, None, None,   123936      ['batch_normalization_27[0][0]']
#                                 32)
#
#  conv2d_29 (Conv2D)             (None, None, None,   1056        ['add_6[0][0]']
#                                 32)
#
#  batch_normalization_28 (BatchN  (None, None, None,   128        ['conv2d_28[0][0]']
#  ormalization)                  32)
#
#  batch_normalization_29 (BatchN  (None, None, None,   128        ['conv2d_29[0][0]']
#  ormalization)                  32)
#
#  conv2d_21 (Conv2D)             (None, None, None,   1056        ['tf.math.divide_no_nan[0][0]']
#                                 32)
#
#  add_7 (Add)                    (None, None, None,   0           ['batch_normalization_28[0][0]',
#                                 32)                               'batch_normalization_29[0][0]']
#
#  batch_normalization_21 (BatchN  (None, None, None,   128        ['conv2d_21[0][0]']
#  ormalization)                  32)
#
#  add_8 (Add)                    (None, None, None,   0           ['add_7[0][0]',
#                                 32)                               'batch_normalization_21[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, None, None,   123936     ['add_8[0][0]']
#  ose)                           32)
#
#  batch_normalization_30 (BatchN  (None, None, None,   128        ['conv2d_transpose[0][0]']
#  ormalization)                  32)
#
#  conv2d_30 (Conv2D)             (None, None, None,   61968       ['batch_normalization_30[0][0]']
#                                 16)
#
#  batch_normalization_31 (BatchN  (None, None, None,   64         ['conv2d_30[0][0]']
#  ormalization)                  16)
#
#  conv2d_31 (Conv2D)             (None, None, None,   30992       ['batch_normalization_31[0][0]']
#                                 16)
#
#  batch_normalization_32 (BatchN  (None, None, None,   64         ['conv2d_31[0][0]']
#  ormalization)                  16)
#
#  conv2d_32 (Conv2D)             (None, None, None,   30992       ['batch_normalization_32[0][0]']
#                                 16)
#
#  conv2d_33 (Conv2D)             (None, None, None,   528         ['batch_normalization_30[0][0]']
#                                 16)
#
#  batch_normalization_33 (BatchN  (None, None, None,   64         ['conv2d_32[0][0]']
#  ormalization)                  16)
#
#  batch_normalization_34 (BatchN  (None, None, None,   64         ['conv2d_33[0][0]']
#  ormalization)                  16)
#
#  add_9 (Add)                    (None, None, None,   0           ['batch_normalization_33[0][0]',
#                                 16)                               'batch_normalization_34[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, None, None,   30992      ['add_9[0][0]']
#  spose)                         16)
#
#  batch_normalization_35 (BatchN  (None, None, None,   64         ['conv2d_transpose_1[0][0]']
#  ormalization)                  16)
#
#  conv2d_34 (Conv2D)             (None, None, None,   15496       ['batch_normalization_35[0][0]']
#                                 8)
#
#  batch_normalization_36 (BatchN  (None, None, None,   32         ['conv2d_34[0][0]']
#  ormalization)                  8)
#
#  conv2d_35 (Conv2D)             (None, None, None,   7752        ['batch_normalization_36[0][0]']
#                                 8)
#
#  batch_normalization_37 (BatchN  (None, None, None,   32         ['conv2d_35[0][0]']
#  ormalization)                  8)
#
#  conv2d_36 (Conv2D)             (None, None, None,   7752        ['batch_normalization_37[0][0]']
#                                 8)
#
#  conv2d_37 (Conv2D)             (None, None, None,   136         ['batch_normalization_35[0][0]']
#                                 8)
#
#  batch_normalization_38 (BatchN  (None, None, None,   32         ['conv2d_36[0][0]']
#  ormalization)                  8)
#
#  batch_normalization_39 (BatchN  (None, None, None,   32         ['conv2d_37[0][0]']
#  ormalization)                  8)
#
#  add_10 (Add)                   (None, None, None,   0           ['batch_normalization_38[0][0]',
#                                 8)                                'batch_normalization_39[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, None, None,   7752       ['add_10[0][0]']
#  spose)                         8)
#
#  batch_normalization_40 (BatchN  (None, None, None,   32         ['conv2d_transpose_2[0][0]']
#  ormalization)                  8)
#
#  conv2d_38 (Conv2D)             (None, None, None,   3876        ['batch_normalization_40[0][0]']
#                                 4)
#
#  batch_normalization_41 (BatchN  (None, None, None,   16         ['conv2d_38[0][0]']
#  ormalization)                  4)
#
#  conv2d_39 (Conv2D)             (None, None, None,   1940        ['batch_normalization_41[0][0]']
#                                 4)
#
#  batch_normalization_42 (BatchN  (None, None, None,   16         ['conv2d_39[0][0]']
#  ormalization)                  4)
#
#  conv2d_40 (Conv2D)             (None, None, None,   1940        ['batch_normalization_42[0][0]']
#                                 4)
#
#  conv2d_41 (Conv2D)             (None, None, None,   36          ['batch_normalization_40[0][0]']
#                                 4)
#
#  batch_normalization_43 (BatchN  (None, None, None,   16         ['conv2d_40[0][0]']
#  ormalization)                  4)
#
#  batch_normalization_44 (BatchN  (None, None, None,   16         ['conv2d_41[0][0]']
#  ormalization)                  4)
#
#  add_11 (Add)                   (None, None, None,   0           ['batch_normalization_43[0][0]',
#                                 4)                                'batch_normalization_44[0][0]']
#
#  conv2d_42 (Conv2D)             (None, None, None,   15          ['add_11[0][0]']
#                                 3)
#
#  tf.math.reduce_min_1 (TFOpLamb  (None, 1, 1, 1)     0           ['conv2d_42[0][0]']
#  da)
#
#  tf.math.reduce_max_1 (TFOpLamb  (None, 1, 1, 1)     0           ['conv2d_42[0][0]']
#  da)
#
#  tf.math.subtract_2 (TFOpLambda  (None, None, None,   0          ['conv2d_42[0][0]',
#  )                              3)                                'tf.math.reduce_min_1[0][0]']
#
#  tf.math.subtract_3 (TFOpLambda  (None, 1, 1, 1)     0           ['tf.math.reduce_max_1[0][0]',
#  )                                                                'tf.math.reduce_min_1[0][0]']
#
#  tf.math.divide_no_nan_1 (TFOpL  (None, None, None,   0          ['tf.math.subtract_2[0][0]',
#  ambda)                         3)                                'tf.math.subtract_3[0][0]']
#
# ==================================================================================================
# Total params: 1,862,527
# Trainable params: 1,860,815
# Non-trainable params: 1,712
# __________________________________________________________________________________________________

# %%
# _,train_img = next(iter(train_ds))
# figsize = (20,20)
# fig = plt.figure(figsize=figsize)
# ax = fig.add_axes([0, 0, 1, 1])
# ax.axis('off')
# ax.imshow(train_img[0,...,0], cmap = 'gray')
# plt.title('Train Image')
# plt.show()

# %%
in_img, gt = next(iter(val_ds))

# %%
in_img.shape
# Out:
# TensorShape([32, 256, 256, 3])

# %%
figsize = (7,7)
fig = plt.figure(figsize=figsize)
ax = fig.add_axes([0, 0, 1, 1])
ax.axis('off')
ax.imshow(in_img[6, ...])
plt.title('Input Image')
plt.show()

# %%
figsize = (7,7)
out_img = model(in_img, training=False)[6, ...]
fig = plt.figure(figsize=figsize)
ax = fig.add_axes([0, 0, 1, 1])
ax.axis('off')
ax.imshow(out_img)
plt.title('Model Output Image')
plt.show()

# %%
np.max(out_img)
# Out:
# 1.0883356

# %%
tf.keras.utils.plot_model(model, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
# !pip install graphviz
# Out:
# Collecting graphviz
#   Downloading graphviz-0.19.1-py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 1.2 MB/s eta 0:00:01
# Installing collected packages: graphviz
# Successfully installed graphviz-0.19.1

# %%
# !apt install graphviz
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# E: Unable to locate package graphviz
